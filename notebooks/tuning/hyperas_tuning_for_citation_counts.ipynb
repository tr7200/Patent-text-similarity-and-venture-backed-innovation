# %% [markdown]
# ## Hyperas tuning on the patent text cosine similarities for citations
#
# Model architecture first defined by the number of features (31) and then tunes on width as well as depth. Also:
#     - optionally adds 1 or 2 layers with the possibility of lower or similar density
#     - gives options of two learnable activation functions as options (PReLU and ELU), both of whch will avoid dead         neurons
#     - gives a validation metric at the end of every trial of loss, a more reliable metric than accuracy
#
# After a preliminary tuning script choosing these hyperparameters, training will use these hyperparameters with the Adam optimizer.

# %%
import os

import subprocess
import platform
import datetime as dt
import pickle
import joblib

import numpy as np
from pandas import read_csv

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from hyperas import optim
from hyperas.distributions import choice, uniform
from hyperopt import (Trials, 
                      STATUS_OK, 
                      tpe)

import keras
from keras.layers.core import (Dense,
                               Dropout, 
                               Activation)
from keras.layers import (BatchNormalization, 
                          PReLU, 
                          ELU) 
from keras.models import Sequential
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.
# /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Using AMD gpu with PlaidML and Metal
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %%
# Reproducibility code - basic information is stored as sheer number of parameters in neural network
# makes true reproducibility nearly impossible
# from: https://making.dia.com/abc-always-be-benchmarking-5854252fc6b1

# save python environment when run
open('hyperas_cosine_similarities_citation_tuning_environment.txt', 'wb').write(subprocess.check_output(['pip', 'list']))
# underlying platform
system = platform.uname()
# python version
python_version = platform.python_version()
# date and time of run
date = dt.datetime.today().strftime("%Y-%m-%d %H:%M:%S")

config = {
    'system': system,
    'python_version': python_version,
    'date': date
}

pickle.dump(config, open('hyperas_cosine_similarities_citation_tuning_config.p', 'wb'))

# %%
FEATURES = 'Patent_text_independent_variables-11-13-19.csv'
TARGET = 'Citation_count_y-11-13-19.csv'

def data(features: str=None,
         target: str=None):
    """Import data, drop ids, scale data between 0 and 1 for activation functions"""
    FEATURES = read_csv(features, header=0)
    TARGET = read_csv(target, header=0)
    train_x, test_x, train_y, test_y= train_test_split(features, 
                                                       target, 
                                                       test_size=0.05, 
                                                       random_state=1)
    x_scaler = MinMaxScaler().fit(train_x)
    train_x = x_scaler.transform(train_x)
    test_x = x_scaler.transform(test_x)
    joblib.dump(x_scaler, "Patent_text_cosine_similarity_data_MinMaxScaler.save")
    
    return train_x, train_y, test_x, test_y

# %%
def model(train_x, 
          train_y, 
          test_x, 
          test_y):
    """Define model"""
    
    '''
    Activation choices - choice of PReLU or ELU, both are 
    learnable and will help avoid oversaturation at either 
    end of the function range (0, 1) that leads to dead 
    neurons--a problem with ReLU and this data since there 
    are many dichotomous binary variables
    '''
    def Activation(name):
        if name == 'PReLU':
            return keras.layers.PReLU()
        if name == 'ELU':
            return keras.layers.ELU()
    
    activationChoice = {{choice(['PReLU', 'ELU'])}}
        
    model = Sequential() 
    model.add(Dense(31, input_shape=(31,), kernel_initializer='he_normal'))
    model.add(Activation(activationChoice))
    model.add(Dense({{choice([22, 24, 26])}}, kernel_initializer='he_normal'))
    model.add(Activation(activationChoice))
    model.add(Dense({{choice([20, 22, 24])}}, kernel_initializer='he_normal'))
    model.add(Activation(activationChoice))
    model.add(Dense({{choice([18, 20, 22])}}, kernel_initializer='he_normal'))
    model.add(Activation(activationChoice))
    
    # Add a fifth layer?
    if {{choice(['none', 'fifth_layer'])}} == 'fifth_layer':
        model.add(Dense({{choice([12, 14, 16, 18])}}, kernel_initializer='he_normal'))
        model.add(Activation(activationChoice))                
        
        # if we add a fifth layer, maybe add a less dense sixth layer?
        if {{choice(['none', 'sixth_layer'])}} == 'sixth_layer':
            model.add(Dense({{choice([10, 12, 14, 16])}}, kernel_initializer='he_normal'))
            model.add(Activation(activationChoice))    
    
    model.add(Dense({{choice([6, 8, 12, 14])}}, kernel_initializer='he_normal'))
    model.add(Activation(activationChoice))
    model.add(Dense({{choice([4, 6, 8, 12])}}, kernel_initializer='he_normal'))
    model.add(Activation(activationChoice))
    model.add(Dense(1, kernel_initializer='he_normal'))
    
    model.compile(loss='mean_squared_error', 
                  metrics=['mae'], 
                  optimizer='adam')

    result = model.fit(train_x, train_y,
              batch_size=16,
              epochs=5,
              verbose=2,
              validation_split=0.05)
    
    # get the lowest validation loss of each training epoch
    validation_loss = np.amin(result.history['val_loss']) 
    print('Best loss of epoch:', validation_loss)
    
    return {'loss': validation_loss, 'status': STATUS_OK, 'model': model}

# %%
train_x, train_y, test_x, test_y = data(FEATURES, TARGET)

# %%
best_run, best_model = optim.minimize(model=model,
                                     data=data,
                                     algo=tpe.suggest,
                                     max_evals=100,    # 100 trials should be enough since a parzen tree is used to 
                                     trials=Trials(),  # choose hyperparameters -- if the loss for a choice isn't 
                                     eval_space=True,  # good, Hyperas won't choose it again - and no optimizers
                                     notebook_name='Hyperas_tuning_for_citation_counts')
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from pandas import read_csv
# except:
#     pass
#
# try:
#     import subprocess
# except:
#     pass
#
# try:
#     import platform
# except:
#     pass
#
# try:
#     import datetime as dt
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import joblib
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import MinMaxScaler
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.layers import BatchNormalization, PReLU, ELU
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from pandas import read_csv
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'activationChoice': hp.choice('activationChoice', ['PReLU', 'ELU']),
#         'Dense': hp.choice('Dense', [22, 24, 26]),
#         'Dense_1': hp.choice('Dense_1', [20, 22, 24]),
#         'Dense_2': hp.choice('Dense_2', [18, 20, 22]),
#         'Dense_3': hp.choice('Dense_3', ['none', 'fifth_layer']),
#         'Dense_4': hp.choice('Dense_4', [12, 14, 16, 18]),
#         'Dense_5': hp.choice('Dense_5', ['none', 'sixth_layer']),
#         'Dense_6': hp.choice('Dense_6', [10, 12, 14, 16]),
#         'Dense_7': hp.choice('Dense_7', [6, 8, 12, 14]),
#         'Dense_8': hp.choice('Dense_8', [4, 6, 8, 12]),
#     }
#
# >>> Data
#   1:
#   2: """
#   3: Importing data, dropping id variables, scaling data between 0 and 1 for benefit of activation functions
#   4: """
#   5: from pandas import read_csv
#   6: indeps = read_csv('Patent_text_independent_variables-11-13-19.csv', header = 0)
#   7: target = read_csv('Citation_count_y-11-13-19.csv', header = 0)
#   8: train_x, test_x, train_y, test_y= train_test_split(indeps, target, test_size = 0.05, random_state = 1)
#   9: x_scaler = MinMaxScaler().fit(train_x)
#  10: train_x = x_scaler.transform(train_x)
#  11: test_x = x_scaler.transform(test_x)
#  12: joblib.dump(x_scaler, "Patent_text_cosine_similarity_data_MinMaxScaler.save")
#  13:
#  14:
#  15:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     """
#    4:     Defining model
#    5:     """
#    6:
#    7:     '''
#    8:     Activation choices - choice of PReLU or ELU, both are learnable and will help avoid oversaturation at either end
#    9:     of the function range (0, 1) that leads to dead neurons--a problem with ReLU and this data since there are many
#   10:     dichotomous binary variables
#   11:     '''
#   12:     def Activation(name):
#   13:         if name == 'PReLU':
#   14:             return keras.layers.PReLU()
#   15:         if name == 'ELU':
#   16:             return keras.layers.ELU()
#   17:
#   18:     activationChoice = space['activationChoice']
#   19:
#   20:     model = Sequential()
#   21:     model.add(Dense(31, input_shape=(31,), kernel_initializer='he_normal'))
#   22:     model.add(Activation(activationChoice))
#   23:     model.add(Dense(space['Dense'], kernel_initializer='he_normal'))
#   24:     model.add(Activation(activationChoice))
#   25:     model.add(Dense(space['Dense_1'], kernel_initializer='he_normal'))
#   26:     model.add(Activation(activationChoice))
#   27:     model.add(Dense(space['Dense_2'], kernel_initializer='he_normal'))
#   28:     model.add(Activation(activationChoice))
#   29:
#   30:     # Add a fifth layer?
#   31:     if space['Dense_3'] == 'seventh_layer':
#   32:         model.add(Dense(space['Dense_4'], kernel_initializer='he_normal'))
#   33:         model.add(Activation(activationChoice))
#   34:
#   35:         # if we add a fifth layer, maybe add a less dense sixth layer?
#   36:         if space['Dense_5'] == 'eighth_layer':
#   37:             model.add(Dense(space['Dense_6'], kernel_initializer='he_normal'))
#   38:             model.add(Activation(activationChoice))
#   39:
#   40:     model.add(Dense(space['Dense_7'], kernel_initializer='he_normal'))
#   41:     model.add(Activation(activationChoice))
#   42:     model.add(Dense(space['Dense_8'], kernel_initializer='he_normal'))
#   43:     model.add(Activation(activationChoice))
#   44:     model.add(Dense(1, kernel_initializer='he_normal'))
#   45:
#   46:     model.compile(loss='mean_squared_error', metrics=['mae'], optimizer='adam')
#   47:
#   48:     result = model.fit(train_x, train_y,
#   49:               batch_size=16,
#   50:               epochs=5,
#   51:               verbose=2,
#   52:               validation_split=0.05)
#   53:
#   54:     # get the lowest validation loss of each training epoch
#   55:     validation_loss = np.amin(result.history['val_loss'])
#   56:     print('Best loss of epoch:', validation_loss)
#   57:     return {'loss': validation_loss, 'status': STATUS_OK, 'model': model}
#   58:
#   0%|          | 0/100 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /miniconda3/envs/keras-env/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 576s - loss: 0.9115 - mean_absolute_error: 0.7586 - val_loss: 0.8659 - val_mean_absolute_error: 0.7353
#
# Epoch 2/5
#  - 578s - loss: 0.8568 - mean_absolute_error: 0.7300 - val_loss: 0.8491 - val_mean_absolute_error: 0.7284
#
# Epoch 3/5
#  - 596s - loss: 0.8443 - mean_absolute_error: 0.7226 - val_loss: 0.8436 - val_mean_absolute_error: 0.7211
#
# Epoch 4/5
#  - 577s - loss: 0.8388 - mean_absolute_error: 0.7188 - val_loss: 0.8346 - val_mean_absolute_error: 0.7165
#
# Epoch 5/5
#  - 579s - loss: 0.8351 - mean_absolute_error: 0.7164 - val_loss: 0.8346 - val_mean_absolute_error: 0.7155
#
# Best loss of epoch:
# 0.8346181151656129
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 482s - loss: 0.9172 - mean_absolute_error: 0.7618 - val_loss: 0.8575 - val_mean_absolute_error: 0.7317
#
# Epoch 2/5
#  - 485s - loss: 0.8588 - mean_absolute_error: 0.7316 - val_loss: 0.8488 - val_mean_absolute_error: 0.7264
#
# Epoch 3/5
#  - 474s - loss: 0.8471 - mean_absolute_error: 0.7246 - val_loss: 0.8439 - val_mean_absolute_error: 0.7199
#
# Epoch 4/5
#  - 485s - loss: 0.8416 - mean_absolute_error: 0.7209 - val_loss: 0.8345 - val_mean_absolute_error: 0.7140
#
# Epoch 5/5
#  - 483s - loss: 0.8383 - mean_absolute_error: 0.7190 - val_loss: 0.8328 - val_mean_absolute_error: 0.7193
#
# Best loss of epoch:
# 0.8327751539044032
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 422s - loss: 0.9130 - mean_absolute_error: 0.7599 - val_loss: 0.8617 - val_mean_absolute_error: 0.7351
#
# Epoch 2/5
#  - 433s - loss: 0.8571 - mean_absolute_error: 0.7312 - val_loss: 0.8431 - val_mean_absolute_error: 0.7255
#
# Epoch 3/5
#  - 428s - loss: 0.8491 - mean_absolute_error: 0.7263 - val_loss: 0.8491 - val_mean_absolute_error: 0.7242
#
# Epoch 4/5
#  - 409s - loss: 0.8458 - mean_absolute_error: 0.7241 - val_loss: 0.8455 - val_mean_absolute_error: 0.7175
#
# Epoch 5/5
#  - 411s - loss: 0.8443 - mean_absolute_error: 0.7226 - val_loss: 0.8518 - val_mean_absolute_error: 0.7237
#
# Best loss of epoch:
# 0.843068984694315
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 414s - loss: 0.9175 - mean_absolute_error: 0.7620 - val_loss: 0.8670 - val_mean_absolute_error: 0.7316
#
# Epoch 2/5
#  - 414s - loss: 0.8628 - mean_absolute_error: 0.7331 - val_loss: 0.8497 - val_mean_absolute_error: 0.7287
#
# Epoch 3/5
#  - 413s - loss: 0.8543 - mean_absolute_error: 0.7281 - val_loss: 0.8421 - val_mean_absolute_error: 0.7217
#
# Epoch 4/5
#  - 415s - loss: 0.8492 - mean_absolute_error: 0.7252 - val_loss: 0.8571 - val_mean_absolute_error: 0.7323
#
# Epoch 5/5
#  - 415s - loss: 0.8458 - mean_absolute_error: 0.7234 - val_loss: 0.8392 - val_mean_absolute_error: 0.7206
#
# Best loss of epoch:
# 0.8392213069920801
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 368s - loss: 0.9201 - mean_absolute_error: 0.7639 - val_loss: 0.8697 - val_mean_absolute_error: 0.7366
#
# Epoch 2/5
#  - 364s - loss: 0.8586 - mean_absolute_error: 0.7319 - val_loss: 0.8506 - val_mean_absolute_error: 0.7235
#
# Epoch 3/5
#  - 361s - loss: 0.8436 - mean_absolute_error: 0.7234 - val_loss: 0.8408 - val_mean_absolute_error: 0.7241
#
# Epoch 4/5
#  - 361s - loss: 0.8391 - mean_absolute_error: 0.7202 - val_loss: 0.8339 - val_mean_absolute_error: 0.7155
#
# Epoch 5/5
#  - 361s - loss: 0.8366 - mean_absolute_error: 0.7187 - val_loss: 0.8325 - val_mean_absolute_error: 0.7154
#
# Best loss of epoch:
# 0.8325191512422804
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 491s - loss: 0.9134 - mean_absolute_error: 0.7593 - val_loss: 0.8595 - val_mean_absolute_error: 0.7332
#
# Epoch 2/5
#  - 481s - loss: 0.8559 - mean_absolute_error: 0.7292 - val_loss: 0.8532 - val_mean_absolute_error: 0.7290
#
# Epoch 3/5
#  - 477s - loss: 0.8449 - mean_absolute_error: 0.7229 - val_loss: 0.8395 - val_mean_absolute_error: 0.7160
#
# Epoch 4/5
#  - 482s - loss: 0.8392 - mean_absolute_error: 0.7197 - val_loss: 0.8354 - val_mean_absolute_error: 0.7196
#
# Epoch 5/5
#  - 489s - loss: 0.8353 - mean_absolute_error: 0.7174 - val_loss: 0.8332 - val_mean_absolute_error: 0.7137
#
# Best loss of epoch:
# 0.8331690925723017
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 377s - loss: 0.9187 - mean_absolute_error: 0.7637 - val_loss: 0.8617 - val_mean_absolute_error: 0.7373
#
# Epoch 2/5
#  - 375s - loss: 0.8549 - mean_absolute_error: 0.7302 - val_loss: 0.8492 - val_mean_absolute_error: 0.7290
#
# Epoch 3/5
#  - 379s - loss: 0.8443 - mean_absolute_error: 0.7234 - val_loss: 0.8348 - val_mean_absolute_error: 0.7177
#
# Epoch 4/5
#  - 389s - loss: 0.8388 - mean_absolute_error: 0.7200 - val_loss: 0.8326 - val_mean_absolute_error: 0.7143
#
# Epoch 5/5
#  - 412s - loss: 0.8370 - mean_absolute_error: 0.7184 - val_loss: 0.8378 - val_mean_absolute_error: 0.7174
#
# Best loss of epoch:
# 0.8325974538332425
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 568s - loss: 0.9142 - mean_absolute_error: 0.7592 - val_loss: 0.8756 - val_mean_absolute_error: 0.7403
#
# Epoch 2/5
#  - 554s - loss: 0.8569 - mean_absolute_error: 0.7294 - val_loss: 0.8490 - val_mean_absolute_error: 0.7249
#
# Epoch 3/5
#  - 544s - loss: 0.8457 - mean_absolute_error: 0.7231 - val_loss: 0.8385 - val_mean_absolute_error: 0.7161
#
# Epoch 4/5
#  - 590s - loss: 0.8406 - mean_absolute_error: 0.7202 - val_loss: 0.8407 - val_mean_absolute_error: 0.7201
#
# Epoch 5/5
#  - 600s - loss: 0.8368 - mean_absolute_error: 0.7180 - val_loss: 0.8339 - val_mean_absolute_error: 0.7179
#
# Best loss of epoch:
# 0.8339037014001027
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 627s - loss: 0.9088 - mean_absolute_error: 0.7578 - val_loss: 0.8763 - val_mean_absolute_error: 0.7352
#
# Epoch 2/5
#  - 598s - loss: 0.8534 - mean_absolute_error: 0.7280 - val_loss: 0.8449 - val_mean_absolute_error: 0.7240
#
# Epoch 3/5
#  - 600s - loss: 0.8440 - mean_absolute_error: 0.7221 - val_loss: 0.8641 - val_mean_absolute_error: 0.7306
#
# Epoch 4/5
#  - 552s - loss: 0.8384 - mean_absolute_error: 0.7188 - val_loss: 0.8438 - val_mean_absolute_error: 0.7186
#
# Epoch 5/5
#  - 584s - loss: 0.8343 - mean_absolute_error: 0.7165 - val_loss: 0.8288 - val_mean_absolute_error: 0.7135
#
# Best loss of epoch:
# 0.8288487806110523
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 450s - loss: 0.9229 - mean_absolute_error: 0.7635 - val_loss: 0.8752 - val_mean_absolute_error: 0.7357
#
# Epoch 2/5
#  - 439s - loss: 0.8639 - mean_absolute_error: 0.7329 - val_loss: 0.8542 - val_mean_absolute_error: 0.7313
#
# Epoch 3/5
#  - 433s - loss: 0.8539 - mean_absolute_error: 0.7272 - val_loss: 0.8478 - val_mean_absolute_error: 0.7221
#
# Epoch 4/5
#  - 450s - loss: 0.8481 - mean_absolute_error: 0.7240 - val_loss: 0.8426 - val_mean_absolute_error: 0.7189
#
# Epoch 5/5
#  - 486s - loss: 0.8448 - mean_absolute_error: 0.7220 - val_loss: 0.8429 - val_mean_absolute_error: 0.7195
#
# Best loss of epoch:
# 0.8426148414558048
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 490s - loss: 0.9134 - mean_absolute_error: 0.7597 - val_loss: 0.8588 - val_mean_absolute_error: 0.7333
#
# Epoch 2/5
#  - 467s - loss: 0.8539 - mean_absolute_error: 0.7276 - val_loss: 0.8358 - val_mean_absolute_error: 0.7171
#
# Epoch 3/5
#  - 446s - loss: 0.8436 - mean_absolute_error: 0.7214 - val_loss: 0.8470 - val_mean_absolute_error: 0.7250
#
# Epoch 4/5
#  - 467s - loss: 0.8385 - mean_absolute_error: 0.7182 - val_loss: 0.8318 - val_mean_absolute_error: 0.7164
#
# Epoch 5/5
#  - 453s - loss: 0.8351 - mean_absolute_error: 0.7164 - val_loss: 0.8405 - val_mean_absolute_error: 0.7245
#
# Best loss of epoch:
# 0.831846823475066
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 530s - loss: 0.9076 - mean_absolute_error: 0.7564 - val_loss: 0.8665 - val_mean_absolute_error: 0.7331
#
# Epoch 2/5
#  - 729s - loss: 0.8561 - mean_absolute_error: 0.7302 - val_loss: 0.8452 - val_mean_absolute_error: 0.7244
#
# Epoch 3/5
#  - 1136s - loss: 0.8470 - mean_absolute_error: 0.7248 - val_loss: 0.8557 - val_mean_absolute_error: 0.7245
#
# Epoch 4/5
#  - 1095s - loss: 0.8428 - mean_absolute_error: 0.7222 - val_loss: 0.8339 - val_mean_absolute_error: 0.7188
#
# Epoch 5/5
#  - 1150s - loss: 0.8403 - mean_absolute_error: 0.7207 - val_loss: 0.8792 - val_mean_absolute_error: 0.7341
#
# Best loss of epoch:
# 0.8339364094347901
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1503s - loss: 0.9131 - mean_absolute_error: 0.7591 - val_loss: 0.8628 - val_mean_absolute_error: 0.7367
#
# Epoch 2/5
#  - 1533s - loss: 0.8579 - mean_absolute_error: 0.7302 - val_loss: 0.8629 - val_mean_absolute_error: 0.7301
#
# Epoch 3/5
#  - 1486s - loss: 0.8510 - mean_absolute_error: 0.7264 - val_loss: 0.8556 - val_mean_absolute_error: 0.7248
#
# Epoch 4/5
#  - 1219s - loss: 0.8474 - mean_absolute_error: 0.7246 - val_loss: 0.8411 - val_mean_absolute_error: 0.7244
#
# Epoch 5/5
#  - 1160s - loss: 0.8455 - mean_absolute_error: 0.7234 - val_loss: 0.8383 - val_mean_absolute_error: 0.7136
#
# Best loss of epoch:
# 0.8382937031970987
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1351s - loss: 0.9218 - mean_absolute_error: 0.7641 - val_loss: 0.8727 - val_mean_absolute_error: 0.7345
#
# Epoch 2/5
#  - 1227s - loss: 0.8643 - mean_absolute_error: 0.7341 - val_loss: 0.8513 - val_mean_absolute_error: 0.7302
#
# Epoch 3/5
#  - 1294s - loss: 0.8526 - mean_absolute_error: 0.7277 - val_loss: 0.8407 - val_mean_absolute_error: 0.7226
#
# Epoch 4/5
#  - 1264s - loss: 0.8459 - mean_absolute_error: 0.7240 - val_loss: 0.8567 - val_mean_absolute_error: 0.7251
#
# Epoch 5/5
#  - 1024s - loss: 0.8426 - mean_absolute_error: 0.7221 - val_loss: 0.8393 - val_mean_absolute_error: 0.7164
#
# Best loss of epoch:
# 0.8392717732996124
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 502s - loss: 0.9203 - mean_absolute_error: 0.7636 - val_loss: 0.8676 - val_mean_absolute_error: 0.7341
#
# Epoch 2/5
#  - 502s - loss: 0.8645 - mean_absolute_error: 0.7352 - val_loss: 0.8611 - val_mean_absolute_error: 0.7374
#
# Epoch 3/5
#  - 496s - loss: 0.8525 - mean_absolute_error: 0.7289 - val_loss: 0.8515 - val_mean_absolute_error: 0.7265
#
# Epoch 4/5
#  - 494s - loss: 0.8465 - mean_absolute_error: 0.7250 - val_loss: 0.8356 - val_mean_absolute_error: 0.7187
#
# Epoch 5/5
#  - 493s - loss: 0.8439 - mean_absolute_error: 0.7237 - val_loss: 0.8361 - val_mean_absolute_error: 0.7205
#
# Best loss of epoch:
# 0.8356236554568719
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 441s - loss: 0.9255 - mean_absolute_error: 0.7659 - val_loss: 0.8666 - val_mean_absolute_error: 0.7321
#
# Epoch 2/5
#  - 441s - loss: 0.8581 - mean_absolute_error: 0.7303 - val_loss: 0.8586 - val_mean_absolute_error: 0.7266
#
# Epoch 3/5
#  - 440s - loss: 0.8430 - mean_absolute_error: 0.7217 - val_loss: 0.8440 - val_mean_absolute_error: 0.7250
#
# Epoch 4/5
#  - 442s - loss: 0.8376 - mean_absolute_error: 0.7182 - val_loss: 0.8626 - val_mean_absolute_error: 0.7194
#
# Epoch 5/5
#  - 446s - loss: 0.8333 - mean_absolute_error: 0.7156 - val_loss: 0.8301 - val_mean_absolute_error: 0.7171
#
# Best loss of epoch:
# 0.8301370732891618
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 457s - loss: 0.9200 - mean_absolute_error: 0.7628 - val_loss: 0.8651 - val_mean_absolute_error: 0.7345
#
# Epoch 2/5
#  - 461s - loss: 0.8552 - mean_absolute_error: 0.7293 - val_loss: 0.8494 - val_mean_absolute_error: 0.7262
#
# Epoch 3/5
#  - 460s - loss: 0.8430 - mean_absolute_error: 0.7222 - val_loss: 0.8338 - val_mean_absolute_error: 0.7152
#
# Epoch 4/5
#  - 465s - loss: 0.8381 - mean_absolute_error: 0.7189 - val_loss: 0.8289 - val_mean_absolute_error: 0.7115
#
# Epoch 5/5
#  - 458s - loss: 0.8352 - mean_absolute_error: 0.7171 - val_loss: 0.8390 - val_mean_absolute_error: 0.7177
#
# Best loss of epoch:
# 0.8289006343055295
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 525s - loss: 0.9237 - mean_absolute_error: 0.7659 - val_loss: 0.8588 - val_mean_absolute_error: 0.7325
#
# Epoch 2/5
#  - 526s - loss: 0.8612 - mean_absolute_error: 0.7322 - val_loss: 0.8552 - val_mean_absolute_error: 0.7270
#
# Epoch 3/5
#  - 517s - loss: 0.8499 - mean_absolute_error: 0.7260 - val_loss: 0.8458 - val_mean_absolute_error: 0.7234
#
# Epoch 4/5
#  - 515s - loss: 0.8448 - mean_absolute_error: 0.7231 - val_loss: 0.8655 - val_mean_absolute_error: 0.7266
#
# Epoch 5/5
#  - 513s - loss: 0.8408 - mean_absolute_error: 0.7207 - val_loss: 0.8332 - val_mean_absolute_error: 0.7172
#
# Best loss of epoch:
# 0.8331697176769779
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 687s - loss: 0.9153 - mean_absolute_error: 0.7607 - val_loss: 0.9002 - val_mean_absolute_error: 0.7449
#
# Epoch 2/5
#  - 683s - loss: 0.8558 - mean_absolute_error: 0.7285 - val_loss: 0.8432 - val_mean_absolute_error: 0.7192
#
# Epoch 3/5
#  - 686s - loss: 0.8447 - mean_absolute_error: 0.7218 - val_loss: 0.8379 - val_mean_absolute_error: 0.7202
#
# Epoch 4/5
#  - 695s - loss: 0.8374 - mean_absolute_error: 0.7172 - val_loss: 0.8401 - val_mean_absolute_error: 0.7163
#
# Epoch 5/5
#  - 703s - loss: 0.8339 - mean_absolute_error: 0.7155 - val_loss: 0.8396 - val_mean_absolute_error: 0.7191
#
# Best loss of epoch:
# 0.8379460823889335
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 542s - loss: 0.9198 - mean_absolute_error: 0.7640 - val_loss: 0.8726 - val_mean_absolute_error: 0.7428
#
# Epoch 2/5
#  - 541s - loss: 0.8633 - mean_absolute_error: 0.7344 - val_loss: 0.8594 - val_mean_absolute_error: 0.7304
#
# Epoch 3/5
#  - 543s - loss: 0.8544 - mean_absolute_error: 0.7297 - val_loss: 0.8423 - val_mean_absolute_error: 0.7244
#
# Epoch 4/5
#  - 544s - loss: 0.8483 - mean_absolute_error: 0.7261 - val_loss: 0.8432 - val_mean_absolute_error: 0.7218
#
# Epoch 5/5
#  - 544s - loss: 0.8474 - mean_absolute_error: 0.7257 - val_loss: 0.8448 - val_mean_absolute_error: 0.7244
#
# Best loss of epoch:
# 0.8423256580906716
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 626s - loss: 0.9138 - mean_absolute_error: 0.7598 - val_loss: 0.8744 - val_mean_absolute_error: 0.7382
#
# Epoch 2/5
#  - 624s - loss: 0.8580 - mean_absolute_error: 0.7310 - val_loss: 0.8487 - val_mean_absolute_error: 0.7291
#
# Epoch 3/5
#  - 616s - loss: 0.8480 - mean_absolute_error: 0.7256 - val_loss: 0.8395 - val_mean_absolute_error: 0.7200
#
# Epoch 4/5
#  - 610s - loss: 0.8418 - mean_absolute_error: 0.7219 - val_loss: 0.8354 - val_mean_absolute_error: 0.7166
#
# Epoch 5/5
#  - 611s - loss: 0.8383 - mean_absolute_error: 0.7196 - val_loss: 0.8371 - val_mean_absolute_error: 0.7201
#
# Best loss of epoch:
# 0.835366368767128
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 625s - loss: 0.9174 - mean_absolute_error: 0.7618 - val_loss: 0.8711 - val_mean_absolute_error: 0.7408
#
# Epoch 2/5
#  - 623s - loss: 0.8594 - mean_absolute_error: 0.7314 - val_loss: 0.8616 - val_mean_absolute_error: 0.7305
#
# Epoch 3/5
#  - 621s - loss: 0.8469 - mean_absolute_error: 0.7243 - val_loss: 0.8347 - val_mean_absolute_error: 0.7182
#
# Epoch 4/5
#  - 627s - loss: 0.8411 - mean_absolute_error: 0.7206 - val_loss: 0.8354 - val_mean_absolute_error: 0.7171
#
# Epoch 5/5
#  - 633s - loss: 0.8377 - mean_absolute_error: 0.7182 - val_loss: 0.8270 - val_mean_absolute_error: 0.7127
#
# Best loss of epoch:
# 0.8270472767148265
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 642s - loss: 0.9172 - mean_absolute_error: 0.7621 - val_loss: 0.8573 - val_mean_absolute_error: 0.7299
#
# Epoch 2/5
#  - 638s - loss: 0.8593 - mean_absolute_error: 0.7315 - val_loss: 0.8479 - val_mean_absolute_error: 0.7267
#
# Epoch 3/5
#  - 640s - loss: 0.8467 - mean_absolute_error: 0.7241 - val_loss: 0.8369 - val_mean_absolute_error: 0.7183
#
# Epoch 4/5
#  - 645s - loss: 0.8408 - mean_absolute_error: 0.7204 - val_loss: 0.8314 - val_mean_absolute_error: 0.7134
#
# Epoch 5/5
#  - 646s - loss: 0.8371 - mean_absolute_error: 0.7180 - val_loss: 0.8326 - val_mean_absolute_error: 0.7140
#
# Best loss of epoch:
# 0.8313870138985768
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 660s - loss: 0.9152 - mean_absolute_error: 0.7607 - val_loss: 0.8684 - val_mean_absolute_error: 0.7374
#
# Epoch 2/5
#  - 659s - loss: 0.8575 - mean_absolute_error: 0.7310 - val_loss: 0.8486 - val_mean_absolute_error: 0.7254
#
# Epoch 3/5
#  - 650s - loss: 0.8470 - mean_absolute_error: 0.7249 - val_loss: 0.8375 - val_mean_absolute_error: 0.7208
#
# Epoch 4/5
#  - 641s - loss: 0.8419 - mean_absolute_error: 0.7220 - val_loss: 0.8412 - val_mean_absolute_error: 0.7195
#
# Epoch 5/5
#  - 637s - loss: 0.8381 - mean_absolute_error: 0.7197 - val_loss: 0.8306 - val_mean_absolute_error: 0.7150
#
# Best loss of epoch:
# 0.8306113259728117
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 646s - loss: 0.9179 - mean_absolute_error: 0.7622 - val_loss: 0.8627 - val_mean_absolute_error: 0.7351
#
# Epoch 2/5
#  - 647s - loss: 0.8554 - mean_absolute_error: 0.7291 - val_loss: 0.8426 - val_mean_absolute_error: 0.7220
#
# Epoch 3/5
#  - 654s - loss: 0.8441 - mean_absolute_error: 0.7224 - val_loss: 0.8364 - val_mean_absolute_error: 0.7207
#
# Epoch 4/5
#  - 658s - loss: 0.8393 - mean_absolute_error: 0.7194 - val_loss: 0.8335 - val_mean_absolute_error: 0.7193
#
# Epoch 5/5
#  - 661s - loss: 0.8362 - mean_absolute_error: 0.7174 - val_loss: 0.8350 - val_mean_absolute_error: 0.7198
#
# Best loss of epoch:
# 0.8335390189108
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 672s - loss: 0.9183 - mean_absolute_error: 0.7616 - val_loss: 0.8682 - val_mean_absolute_error: 0.7384
#
# Epoch 2/5
#  - 675s - loss: 0.8607 - mean_absolute_error: 0.7318 - val_loss: 0.8458 - val_mean_absolute_error: 0.7217
#
# Epoch 3/5
#  - 675s - loss: 0.8477 - mean_absolute_error: 0.7248 - val_loss: 0.8374 - val_mean_absolute_error: 0.7174
#
# Epoch 4/5
#  - 715s - loss: 0.8414 - mean_absolute_error: 0.7211 - val_loss: 0.8349 - val_mean_absolute_error: 0.7188
#
# Epoch 5/5
#  - 787s - loss: 0.8371 - mean_absolute_error: 0.7186 - val_loss: 0.8372 - val_mean_absolute_error: 0.7201
#
# Best loss of epoch:
# 0.8349314394387624
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 837s - loss: 0.9183 - mean_absolute_error: 0.7614 - val_loss: 0.8796 - val_mean_absolute_error: 0.7374
#
# Epoch 2/5
#  - 769s - loss: 0.8583 - mean_absolute_error: 0.7303 - val_loss: 0.8499 - val_mean_absolute_error: 0.7238
#
# Epoch 3/5
#  - 791s - loss: 0.8462 - mean_absolute_error: 0.7235 - val_loss: 0.8430 - val_mean_absolute_error: 0.7216
#
# Epoch 4/5
#  - 722s - loss: 0.8404 - mean_absolute_error: 0.7202 - val_loss: 0.8421 - val_mean_absolute_error: 0.7193
#
# Epoch 5/5
#  - 733s - loss: 0.8367 - mean_absolute_error: 0.7180 - val_loss: 0.8277 - val_mean_absolute_error: 0.7119
#
# Best loss of epoch:
# 0.8277419048779628
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 756s - loss: 0.9152 - mean_absolute_error: 0.7600 - val_loss: 0.8923 - val_mean_absolute_error: 0.7363
#
# Epoch 2/5
#  - 899s - loss: 0.8550 - mean_absolute_error: 0.7291 - val_loss: 0.8471 - val_mean_absolute_error: 0.7256
#
# Epoch 3/5
#  - 853s - loss: 0.8458 - mean_absolute_error: 0.7241 - val_loss: 0.8571 - val_mean_absolute_error: 0.7293
#
# Epoch 4/5
#  - 936s - loss: 0.8408 - mean_absolute_error: 0.7210 - val_loss: 0.8453 - val_mean_absolute_error: 0.7204
#
# Epoch 5/5
#  - 873s - loss: 0.8368 - mean_absolute_error: 0.7187 - val_loss: 0.8569 - val_mean_absolute_error: 0.7305
#
# Best loss of epoch:
# 0.8453219808513756
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 851s - loss: 0.9147 - mean_absolute_error: 0.7597 - val_loss: 0.8582 - val_mean_absolute_error: 0.7340
#
# Epoch 2/5
#  - 896s - loss: 0.8568 - mean_absolute_error: 0.7298 - val_loss: 0.8555 - val_mean_absolute_error: 0.7269
#
# Epoch 3/5
#  - 960s - loss: 0.8464 - mean_absolute_error: 0.7239 - val_loss: 0.8396 - val_mean_absolute_error: 0.7197
# Epoch 4/5
#  - 859s - loss: 0.8411 - mean_absolute_error: 0.7206 - val_loss: 0.8365 - val_mean_absolute_error: 0.7150
#
# Epoch 5/5
#  - 863s - loss: 0.8376 - mean_absolute_error: 0.7185 - val_loss: 0.8628 - val_mean_absolute_error: 0.7301
#
# Best loss of epoch:
# 0.8365258524598952
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 990s - loss: 0.9129 - mean_absolute_error: 0.7591 - val_loss: 0.8634 - val_mean_absolute_error: 0.7338
#
# Epoch 2/5
#  - 804s - loss: 0.8561 - mean_absolute_error: 0.7292 - val_loss: 0.8452 - val_mean_absolute_error: 0.7207
#
# Epoch 3/5
#  - 835s - loss: 0.8445 - mean_absolute_error: 0.7226 - val_loss: 0.8493 - val_mean_absolute_error: 0.7227
#
# Epoch 4/5
#  - 894s - loss: 0.8392 - mean_absolute_error: 0.7194 - val_loss: 0.8408 - val_mean_absolute_error: 0.7169
#
# Epoch 5/5
#  - 849s - loss: 0.8354 - mean_absolute_error: 0.7173 - val_loss: 0.8337 - val_mean_absolute_error: 0.7184
#
# Best loss of epoch:
# 0.8337433230446923
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 726s - loss: 0.9165 - mean_absolute_error: 0.7609 - val_loss: 0.8540 - val_mean_absolute_error: 0.7271
#
# Epoch 2/5
#  - 697s - loss: 0.8584 - mean_absolute_error: 0.7299 - val_loss: 0.8426 - val_mean_absolute_error: 0.7224
#
# Epoch 3/5
#  - 724s - loss: 0.8480 - mean_absolute_error: 0.7239 - val_loss: 0.8365 - val_mean_absolute_error: 0.7201
#
# Epoch 4/5
#  - 757s - loss: 0.8413 - mean_absolute_error: 0.7201 - val_loss: 0.8521 - val_mean_absolute_error: 0.7239
#
# Epoch 5/5
#  - 715s - loss: 0.8402 - mean_absolute_error: 0.7195 - val_loss: 0.8595 - val_mean_absolute_error: 0.7269
#
# Best loss of epoch:
# 0.8364856213658735
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 784s - loss: 0.9123 - mean_absolute_error: 0.7588 - val_loss: 0.8551 - val_mean_absolute_error: 0.7281
#
# Epoch 2/5
#  - 778s - loss: 0.8553 - mean_absolute_error: 0.7290 - val_loss: 0.8435 - val_mean_absolute_error: 0.7237
#
# Epoch 3/5
#  - 788s - loss: 0.8450 - mean_absolute_error: 0.7230 - val_loss: 0.8386 - val_mean_absolute_error: 0.7170
#
# Epoch 4/5
#  - 819s - loss: 0.8390 - mean_absolute_error: 0.7196 - val_loss: 0.8354 - val_mean_absolute_error: 0.7171
#
# Epoch 5/5
#  - 811s - loss: 0.8354 - mean_absolute_error: 0.7176 - val_loss: 0.8390 - val_mean_absolute_error: 0.7185
#
# Best loss of epoch:
# 0.8353980300656402
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 863s - loss: 0.9176 - mean_absolute_error: 0.7622 - val_loss: 0.8694 - val_mean_absolute_error: 0.7382
#
# Epoch 2/5
#  - 817s - loss: 0.8585 - mean_absolute_error: 0.7312 - val_loss: 0.8578 - val_mean_absolute_error: 0.7301
#
# Epoch 3/5
#  - 796s - loss: 0.8464 - mean_absolute_error: 0.7240 - val_loss: 0.8368 - val_mean_absolute_error: 0.7173
#
# Epoch 4/5
#  - 817s - loss: 0.8395 - mean_absolute_error: 0.7199 - val_loss: 0.8447 - val_mean_absolute_error: 0.7224
#
# Epoch 5/5
#  - 821s - loss: 0.8355 - mean_absolute_error: 0.7175 - val_loss: 0.8310 - val_mean_absolute_error: 0.7162
#
# Best loss of epoch:
# 0.8309761202799628
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 805s - loss: 0.9144 - mean_absolute_error: 0.7603 - val_loss: 0.8634 - val_mean_absolute_error: 0.7318
#
# Epoch 2/5
#  - 832s - loss: 0.8551 - mean_absolute_error: 0.7292 - val_loss: 0.8443 - val_mean_absolute_error: 0.7219
#
# Epoch 3/5
#  - 1037s - loss: 0.8452 - mean_absolute_error: 0.7233 - val_loss: 0.8358 - val_mean_absolute_error: 0.7180
#
# Epoch 4/5
#  - 1901s - loss: 0.8382 - mean_absolute_error: 0.7190 - val_loss: 0.8331 - val_mean_absolute_error: 0.7156
#
# Epoch 5/5
#  - 1546s - loss: 0.8349 - mean_absolute_error: 0.7168 - val_loss: 0.8280 - val_mean_absolute_error: 0.7140
#
# Best loss of epoch:
# 0.8279661164612013
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 898s - loss: 0.9145 - mean_absolute_error: 0.7611 - val_loss: 0.8644 - val_mean_absolute_error: 0.7325
#
# Epoch 2/5
#  - 834s - loss: 0.8558 - mean_absolute_error: 0.7309 - val_loss: 0.8467 - val_mean_absolute_error: 0.7235
#
# Epoch 3/5
# ...
#  - 1641s - loss: 0.8543 - mean_absolute_error: 0.7277 - val_loss: 0.8428 - val_mean_absolute_error: 0.7237
#
# Epoch 3/5
#  - 1648s - loss: 0.8444 - mean_absolute_error: 0.7218 - val_loss: 0.8422 - val_mean_absolute_error: 0.7205
# Epoch 4/5
#  - 1644s - loss: 0.8375 - mean_absolute_error: 0.7177 - val_loss: 0.8373 - val_mean_absolute_error: 0.7169
#
# Epoch 5/5
#  - 1641s - loss: 0.8340 - mean_absolute_error: 0.7154 - val_loss: 0.8323 - val_mean_absolute_error: 0.7091
#
# Best loss of epoch:
# 0.8322584835010653
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1514s - loss: 0.9196 - mean_absolute_error: 0.7637 - val_loss: 0.8803 - val_mean_absolute_error: 0.7413
#
# Epoch 2/5
#  - 1507s - loss: 0.8632 - mean_absolute_error: 0.7344 - val_loss: 0.8539 - val_mean_absolute_error: 0.7310
#
# Epoch 3/5
#  - 1505s - loss: 0.8513 - mean_absolute_error: 0.7277 - val_loss: 0.8479 - val_mean_absolute_error: 0.7273
#
# Epoch 4/5
#  - 1506s - loss: 0.8462 - mean_absolute_error: 0.7248 - val_loss: 0.8370 - val_mean_absolute_error: 0.7182
#
# Epoch 5/5
#  - 1506s - loss: 0.8410 - mean_absolute_error: 0.7216 - val_loss: 0.8363 - val_mean_absolute_error: 0.7171
#
# Best loss of epoch:
# 0.8363431029300729
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1338s - loss: 0.9256 - mean_absolute_error: 0.7657 - val_loss: 0.8639 - val_mean_absolute_error: 0.7334
#
# Epoch 2/5
#  - 1321s - loss: 0.8598 - mean_absolute_error: 0.7311 - val_loss: 0.8556 - val_mean_absolute_error: 0.7286
#
# Epoch 3/5
#  - 1310s - loss: 0.8500 - mean_absolute_error: 0.7253 - val_loss: 0.8414 - val_mean_absolute_error: 0.7215
#
# Epoch 4/5
#  - 1316s - loss: 0.8440 - mean_absolute_error: 0.7221 - val_loss: 0.8412 - val_mean_absolute_error: 0.7209
#
# Epoch 5/5
#  - 1319s - loss: 0.8412 - mean_absolute_error: 0.7206 - val_loss: 0.8404 - val_mean_absolute_error: 0.7187
#
# Best loss of epoch:
# 0.8403597718281094
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1545s - loss: 0.9103 - mean_absolute_error: 0.7580 - val_loss: 0.8566 - val_mean_absolute_error: 0.7311
#
# Epoch 2/5
#  - 1534s - loss: 0.8555 - mean_absolute_error: 0.7295 - val_loss: 0.8369 - val_mean_absolute_error: 0.7220
#
# Epoch 3/5
#  - 1534s - loss: 0.8444 - mean_absolute_error: 0.7229 - val_loss: 0.8396 - val_mean_absolute_error: 0.7156
#
# Epoch 4/5
#  - 1544s - loss: 0.8383 - mean_absolute_error: 0.7193 - val_loss: 0.8389 - val_mean_absolute_error: 0.7171
#
# Epoch 5/5
#  - 1547s - loss: 0.8344 - mean_absolute_error: 0.7168 - val_loss: 0.8282 - val_mean_absolute_error: 0.7163
#
# Best loss of epoch:
# 0.8281831030734045
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1640s - loss: 0.9176 - mean_absolute_error: 0.7624 - val_loss: 0.8728 - val_mean_absolute_error: 0.7392
#
# Epoch 2/5
#  - 1624s - loss: 0.8607 - mean_absolute_error: 0.7318 - val_loss: 0.8502 - val_mean_absolute_error: 0.7274
#
# Epoch 3/5
#  - 1616s - loss: 0.8484 - mean_absolute_error: 0.7247 - val_loss: 0.8363 - val_mean_absolute_error: 0.7181
#
# Epoch 4/5
#  - 1624s - loss: 0.8428 - mean_absolute_error: 0.7214 - val_loss: 0.8394 - val_mean_absolute_error: 0.7168
#
# Epoch 5/5
#  - 1622s - loss: 0.8389 - mean_absolute_error: 0.7192 - val_loss: 0.8410 - val_mean_absolute_error: 0.7232
#
# Best loss of epoch:
# 0.8362532036097047
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1573s - loss: 0.9105 - mean_absolute_error: 0.7591 - val_loss: 0.8693 - val_mean_absolute_error: 0.7369
#
# Epoch 2/5
#  - 1569s - loss: 0.8541 - mean_absolute_error: 0.7290 - val_loss: 0.8507 - val_mean_absolute_error: 0.7297
#
# Epoch 3/5
#  - 1567s - loss: 0.8428 - mean_absolute_error: 0.7221 - val_loss: 0.8360 - val_mean_absolute_error: 0.7188
#
# Epoch 4/5
#  - 1730s - loss: 0.8372 - mean_absolute_error: 0.7185 - val_loss: 0.8356 - val_mean_absolute_error: 0.7189
#
# Epoch 5/5
#  - 3214s - loss: 0.8342 - mean_absolute_error: 0.7165 - val_loss: 0.8409 - val_mean_absolute_error: 0.7193
#
# Best loss of epoch:
# 0.8355743090044517
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1950s - loss: 0.9236 - mean_absolute_error: 0.7650 - val_loss: 0.8651 - val_mean_absolute_error: 0.7336
#
# Epoch 2/5
#  - 1503s - loss: 0.8579 - mean_absolute_error: 0.7306 - val_loss: 0.8504 - val_mean_absolute_error: 0.7270
#
# Epoch 3/5
#  - 1503s - loss: 0.8472 - mean_absolute_error: 0.7240 - val_loss: 0.8478 - val_mean_absolute_error: 0.7210
#
# Epoch 4/5
#  - 1505s - loss: 0.8432 - mean_absolute_error: 0.7216 - val_loss: 0.8360 - val_mean_absolute_error: 0.7155
#
# Epoch 5/5
#  - 1504s - loss: 0.8382 - mean_absolute_error: 0.7188 - val_loss: 0.8340 - val_mean_absolute_error: 0.7188
#
# Best loss of epoch:
# 0.8340174347937245
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1750s - loss: 0.9120 - mean_absolute_error: 0.7591 - val_loss: 0.8574 - val_mean_absolute_error: 0.7311
#
# Epoch 2/5
#  - 1739s - loss: 0.8543 - mean_absolute_error: 0.7284 - val_loss: 0.8583 - val_mean_absolute_error: 0.7287
#
# Epoch 3/5
#  - 1735s - loss: 0.8441 - mean_absolute_error: 0.7225 - val_loss: 0.8432 - val_mean_absolute_error: 0.7194
#
# Epoch 4/5
#  - 1739s - loss: 0.8389 - mean_absolute_error: 0.7194 - val_loss: 0.8350 - val_mean_absolute_error: 0.7202
#
# Epoch 5/5
#  - 1741s - loss: 0.8348 - mean_absolute_error: 0.7169 - val_loss: 0.8321 - val_mean_absolute_error: 0.7143
#
# Best loss of epoch:
# 0.8321092904829871
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1790s - loss: 0.9119 - mean_absolute_error: 0.7583 - val_loss: 0.8573 - val_mean_absolute_error: 0.7277
#
# Epoch 2/5
#  - 1776s - loss: 0.8538 - mean_absolute_error: 0.7280 - val_loss: 0.8407 - val_mean_absolute_error: 0.7241
#
# Epoch 3/5
#  - 1777s - loss: 0.8432 - mean_absolute_error: 0.7218 - val_loss: 0.8412 - val_mean_absolute_error: 0.7184
#
# Epoch 4/5
#  - 1778s - loss: 0.8384 - mean_absolute_error: 0.7190 - val_loss: 0.8413 - val_mean_absolute_error: 0.7214
#
# Epoch 5/5
#  - 2103s - loss: 0.8349 - mean_absolute_error: 0.7171 - val_loss: 0.8281 - val_mean_absolute_error: 0.7113
#
# Best loss of epoch:
# 0.828119240751167
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 2370s - loss: 0.9132 - mean_absolute_error: 0.7603 - val_loss: 0.8686 - val_mean_absolute_error: 0.7310
#
# Epoch 2/5
#  - 1976s - loss: 0.8539 - mean_absolute_error: 0.7277 - val_loss: 0.8437 - val_mean_absolute_error: 0.7204
#
# Epoch 3/5
#  - 1973s - loss: 0.8428 - mean_absolute_error: 0.7214 - val_loss: 0.8429 - val_mean_absolute_error: 0.7229
#
# Epoch 4/5
#  - 1969s - loss: 0.8373 - mean_absolute_error: 0.7180 - val_loss: 0.8340 - val_mean_absolute_error: 0.7158
#
# Epoch 5/5
#  - 1967s - loss: 0.8341 - mean_absolute_error: 0.7160 - val_loss: 0.8385 - val_mean_absolute_error: 0.7182
#
# Best loss of epoch:
# 0.834035248061174
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1846s - loss: 0.9162 - mean_absolute_error: 0.7603 - val_loss: 0.8614 - val_mean_absolute_error: 0.7320
#
# Epoch 2/5
#  - 1835s - loss: 0.8593 - mean_absolute_error: 0.7308 - val_loss: 0.8625 - val_mean_absolute_error: 0.7305
#
# Epoch 3/5
#  - 1837s - loss: 0.8470 - mean_absolute_error: 0.7239 - val_loss: 0.8457 - val_mean_absolute_error: 0.7230
#
# Epoch 4/5
#  - 1835s - loss: 0.8414 - mean_absolute_error: 0.7205 - val_loss: 0.8369 - val_mean_absolute_error: 0.7159
#
# Epoch 5/5
#  - 1831s - loss: 0.8377 - mean_absolute_error: 0.7180 - val_loss: 0.8298 - val_mean_absolute_error: 0.7125
#
# Best loss of epoch:
# 0.829848857435501
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1640s - loss: 0.9148 - mean_absolute_error: 0.7607 - val_loss: 0.8731 - val_mean_absolute_error: 0.7372
#
# Epoch 2/5
#  - 1613s - loss: 0.8527 - mean_absolute_error: 0.7280 - val_loss: 0.8531 - val_mean_absolute_error: 0.7248
#
# Epoch 3/5
#  - 1635s - loss: 0.8422 - mean_absolute_error: 0.7219 - val_loss: 0.8335 - val_mean_absolute_error: 0.7174
#
# Epoch 4/5
#  - 1623s - loss: 0.8371 - mean_absolute_error: 0.7188 - val_loss: 0.8388 - val_mean_absolute_error: 0.7204
#
# Epoch 5/5
#  - 1627s - loss: 0.8344 - mean_absolute_error: 0.7172 - val_loss: 0.8294 - val_mean_absolute_error: 0.7152
#
# Best loss of epoch:
# 0.8294079512854068
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1891s - loss: 0.9166 - mean_absolute_error: 0.7616 - val_loss: 0.8698 - val_mean_absolute_error: 0.7380
#
# Epoch 2/5
#  - 1890s - loss: 0.8595 - mean_absolute_error: 0.7317 - val_loss: 0.8525 - val_mean_absolute_error: 0.7302
#
# Epoch 3/5
#  - 1878s - loss: 0.8463 - mean_absolute_error: 0.7242 - val_loss: 0.8366 - val_mean_absolute_error: 0.7202
#
# Epoch 4/5
#  - 1901s - loss: 0.8402 - mean_absolute_error: 0.7210 - val_loss: 0.8356 - val_mean_absolute_error: 0.7168
#
# Epoch 5/5
#  - 1892s - loss: 0.8366 - mean_absolute_error: 0.7186 - val_loss: 0.8326 - val_mean_absolute_error: 0.7174
#
# Best loss of epoch:
# 0.8326284568590597
# 100%|██████████| 100/100 [147:52:46<00:00, 5323.67s/it, best loss: 0.8247945574935982]

# %%
print("Hyper-parameters of best model in order:")

print(best_run)
# Out:
# Hyper-parameters of best model in order:
# {'Dense': 22, 'Dense_1': 24, 'Dense_2': 20, 'Dense_3': 'none', 'Dense_4': 18, 'Dense_5': 'sixth_layer', 'Dense_6': 16, 'Dense_7': 6, 'Dense_8': 8, 'activationChoice': 'PReLU'}
