# %% [markdown]
# ## Hyperas tuning on the patent text cosine similarities for patents
#
# Model architecture first defined by the number of features (31) and then tunes on width as well as depth. Also:
#     - optionally adds 1 or 2 layers with the possibility of lower or similar density
#     - gives options of two learnable activation functions as options (PReLU and ELU), both of whch will avoid dead         neurons
#     - gives a validation metric at the end of every trial of loss, a more reliable metric than accuracy
#
# After a preliminary tuning script choosing these hyperparameters, training will use these hyperparameters with the Adam optimizer.

# %%
import os

import subprocess
import platform
import datetime as dt
import pickle
import joblib

import numpy as np
from pandas import read_csv

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

from hyperas import optim
from hyperas.distributions import choice, uniform
from hyperopt import (Trials, 
                      STATUS_OK, 
                      tpe)

import keras
from keras.layers.core import (Dense, 
                               Dropout, 
                               Activation)
from keras.layers import (BatchNormalization, 
                          PReLU, 
                          ELU) 
from keras.models import Sequential
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.
# C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# Using AMD gpu with PlaidML and Metal  -- PlaidML stopped working for me after updating MacOS :(
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# %%
# Reproducibility code - basic information is stored as sheer number of parameters in neural network
# makes true reproducibility nearly impossible
# from: https://making.dia.com/abc-always-be-benchmarking-5854252fc6b1

# save python environment when run
open('hyperas_cosine_similarities_patent_tuning_environment.txt', 'wb').write(subprocess.check_output(['pip', 'list'], shell=True))
# underlying platform
system = platform.uname()
# python version
python_version = platform.python_version()
# date and time of run
date = dt.datetime.today().strftime("%Y-%m-%d %H:%M:%S")

config = {
    'system': system,
    'python_version': python_version,
    'date': date
}

pickle.dump(config, open('hyperas_cosine_similarities_patent_tuning_config.p', 'wb'))

# %%
FEATURES = 'Patent_text_independent_variables-11-13-19.csv'
TARGET = 'Patent_count_y-11-13-19.csv'

def data(features: str=None,
         target: str=None):
    """Import data, drop ids, scale data between 0 and 1 for activation functions"""
    features = read_csv(features, header = 0)
    target = read_csv(target, header = 0)
    train_x, test_x, train_y, test_y= train_test_split(features, 
                                                       target, 
                                                       test_size=0.05, 
                                                       random_state=1)
    x_scaler = MinMaxScaler().fit(train_x)
    train_x = x_scaler.transform(train_x)
    test_x = x_scaler.transform(test_x)
    joblib.dump(x_scaler, "Patent_text_cosine_similarity_data_MinMaxScaler.save")
    
    return train_x, train_y, test_x, test_y

# %%
def model(train_x, 
          train_y, 
          test_x, 
          test_y):
    """Define model"""
    
    '''
    Activation choices - choice of PReLU or ELU, both 
    are learnable and will help avoid oversaturation 
    at either end of the function range (0, 1) that 
    leads to dead neurons--a problem with ReLU and 
    this data since there are many dichotomous binary 
    variables
    '''
    def Activation(name):
        """fcn necessary for advanced activations with Hyperas"""
        if name == 'PReLU':
            return keras.layers.PReLU()
        if name == 'ELU':
            return keras.layers.ELU()
    
    activation_choice = {{choice(['PReLU', 'ELU'])}}
        
    model = Sequential() 
    model.add(Dense(31, input_shape=(31,), kernel_initializer='he_normal'))
    model.add(Activation(activation_choice))
    model.add(Dense({{choice([22, 24, 26])}}, kernel_initializer='he_normal'))
    model.add(Activation(activation_choice))
    model.add(Dense({{choice([20, 22, 24])}}, kernel_initializer='he_normal'))
    model.add(Activation(activation_choice))
    model.add(Dense({{choice([18, 20, 22])}}, kernel_initializer='he_normal'))
    model.add(Activation(activation_choice))
    
    # Add a fifth layer?
    if {{choice(['none', 'fifth_layer'])}} == 'fifth_layer':
        model.add(Dense({{choice([12, 14, 16, 18])}}, kernel_initializer='he_normal'))
        model.add(Activation(activation_choice))                
        
        # if we add a fifth layer, maybe add a less dense sixth layer?
        if {{choice(['none', 'sixth_layer'])}} == 'sixth_layer':
            model.add(Dense({{choice([10, 12, 14, 16])}}, kernel_initializer='he_normal'))
            model.add(Activation(activation_choice))    
    
    model.add(Dense({{choice([6, 8, 12, 14])}}, kernel_initializer='he_normal'))
    model.add(Activation(activation_choice))
    model.add(Dense({{choice([4, 6, 8, 12])}}, kernel_initializer='he_normal'))
    model.add(Activation(activation_choice))
    model.add(Dense(1, kernel_initializer='he_normal'))
    
    model.compile(loss='mean_squared_error', 
                  metrics=['mae'], 
                  optimizer='adam')

    result = model.fit(train_x, 
                       train_y,
                       batch_size=16,
                       epochs=5,
                       verbose=2,
                       validation_split=0.05)
    
    # get the lowest validation loss of each training epoch
    validation_loss = np.amin(result.history['val_loss']) 
    print('Best loss of epoch:', validation_loss)
    
    return {'loss': validation_loss, 'status': STATUS_OK, 'model': model}

# %%
train_x, train_y, test_x, test_y = data(FEATURES, TARGET)

# %%
best_run, best_model = optim.minimize(model=model,
                                     data=data,
                                     algo=tpe.suggest,
                                     max_evals=100,    # 100 trials should be enough since a parzen tree is used to 
                                     trials=Trials(),  # choose hyperparameters -- if the loss for a choice isn't 
                                     eval_space=True,  # good, Hyperas won't choose it again - and no optimizers
                                     notebook_name='Hyperas_tuning_for_patent_counts')
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import os
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from pandas import read_csv
# except:
#     pass
#
# try:
#     import subprocess
# except:
#     pass
#
# try:
#     import platform
# except:
#     pass
#
# try:
#     import datetime as dt
# except:
#     pass
#
# try:
#     import pickle
# except:
#     pass
#
# try:
#     import joblib
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import MinMaxScaler
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     import keras
# except:
#     pass
#
# try:
#     from keras.layers.core import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.layers import BatchNormalization, PReLU, ELU
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'activationChoice': hp.choice('activationChoice', ['PReLU', 'ELU']),
#         'Dense': hp.choice('Dense', [22, 24, 26]),
#         'Dense_1': hp.choice('Dense_1', [20, 22, 24]),
#         'Dense_2': hp.choice('Dense_2', [18, 20, 22]),
#         'Dense_3': hp.choice('Dense_3', ['none', 'fifth_layer']),
#         'Dense_4': hp.choice('Dense_4', [12, 14, 16, 18]),
#         'Dense_5': hp.choice('Dense_5', ['none', 'sixth_layer']),
#         'Dense_6': hp.choice('Dense_6', [10, 12, 14, 16]),
#         'Dense_7': hp.choice('Dense_7', [6, 8, 12, 14]),
#         'Dense_8': hp.choice('Dense_8', [4, 6, 8, 12]),
#     }
#
# >>> Data
#   1:
#   2: """
#   3: Importing data, dropping id variables, scaling data between 0 and 1 for benefit of activation functions
#   4: """
#   5: indeps = read_csv('Patent_text_independent_variables-11-13-19.csv', header = 0)
#   6: target = read_csv('Patent_count_y-11-13-19.csv', header = 0)
#   7: train_x, test_x, train_y, test_y= train_test_split(indeps, target, test_size = 0.05, random_state = 1)
#   8: x_scaler = MinMaxScaler().fit(train_x)
#   9: train_x = x_scaler.transform(train_x)
#  10: test_x = x_scaler.transform(test_x)
#  11: joblib.dump(x_scaler, "Patent_text_cosine_similarity_data_MinMaxScaler.save")
#  12:
#  13:
#  14:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:     """
#    4:     Defining model
#    5:     """
#    6:
#    7:     '''
#    8:     Activation choices - choice of PReLU or ELU, both are learnable and will help avoid oversaturation at either end
#    9:     of the function range (0, 1) that leads to dead neurons--a problem with ReLU and this data since there are many
#   10:     dichotomous binary variables
#   11:     '''
#   12:     def Activation(name):
#   13:         if name == 'PReLU':
#   14:             return keras.layers.PReLU()
#   15:         if name == 'ELU':
#   16:             return keras.layers.ELU()
#   17:
#   18:     activationChoice = space['activationChoice']
#   19:
#   20:     model = Sequential()
#   21:     model.add(Dense(31, input_shape=(31,), kernel_initializer='he_normal'))
#   22:     model.add(Activation(activationChoice))
#   23:     model.add(Dense(space['Dense'], kernel_initializer='he_normal'))
#   24:     model.add(Activation(activationChoice))
#   25:     model.add(Dense(space['Dense_1'], kernel_initializer='he_normal'))
#   26:     model.add(Activation(activationChoice))
#   27:     model.add(Dense(space['Dense_2'], kernel_initializer='he_normal'))
#   28:     model.add(Activation(activationChoice))
#   29:
#   30:     # Add a fifth layer?
#   31:     if space['Dense_3'] == 'seventh_layer':
#   32:         model.add(Dense(space['Dense_4'], kernel_initializer='he_normal'))
#   33:         model.add(Activation(activationChoice))
#   34:
#   35:         # if we add a fifth layer, maybe add a less dense sixth layer?
#   36:         if space['Dense_5'] == 'eighth_layer':
#   37:             model.add(Dense(space['Dense_6'], kernel_initializer='he_normal'))
#   38:             model.add(Activation(activationChoice))
#   39:
#   40:     model.add(Dense(space['Dense_7'], kernel_initializer='he_normal'))
#   41:     model.add(Activation(activationChoice))
#   42:     model.add(Dense(space['Dense_8'], kernel_initializer='he_normal'))
#   43:     model.add(Activation(activationChoice))
#   44:     model.add(Dense(1, kernel_initializer='he_normal'))
#   45:
#   46:     model.compile(loss='mean_squared_error', metrics=['mae'], optimizer='adam')
#   47:
#   48:     result = model.fit(train_x, train_y,
#   49:               batch_size=16,
#   50:               epochs=5,
#   51:               verbose=2,
#   52:               validation_split=0.05)
#   53:
#   54:     # get the lowest validation loss of each training epoch
#   55:     validation_loss = np.amin(result.history['val_loss'])
#   56:     print('Best loss of epoch:', validation_loss)
#   57:     return {'loss': validation_loss, 'status': STATUS_OK, 'model': model}
#   58:
#   0%|          | 0/100 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:From C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\troge\.conda\envs\keras-env\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1384s - loss: 0.0771 - mean_absolute_error: 0.2016 - val_loss: 0.0684 - val_mean_absolute_error: 0.1902
#
# Epoch 2/5
#  - 1529s - loss: 0.0676 - mean_absolute_error: 0.1847 - val_loss: 0.0690 - val_mean_absolute_error: 0.1863
#
# Epoch 3/5
#  - 786s - loss: 0.0663 - mean_absolute_error: 0.1819 - val_loss: 0.0659 - val_mean_absolute_error: 0.1857
#
# Epoch 4/5
#  - 787s - loss: 0.0655 - mean_absolute_error: 0.1804 - val_loss: 0.0649 - val_mean_absolute_error: 0.1814
#
# Epoch 5/5
#  - 1212s - loss: 0.0661 - mean_absolute_error: 0.1828 - val_loss: 0.0649 - val_mean_absolute_error: 0.1766
#
# Best loss of epoch:
# 0.0649224812063466
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1154s - loss: 0.0777 - mean_absolute_error: 0.2025 - val_loss: 0.0684 - val_mean_absolute_error: 0.1832
#
# Epoch 2/5
#  - 1149s - loss: 0.0678 - mean_absolute_error: 0.1855 - val_loss: 0.0651 - val_mean_absolute_error: 0.1804
#
# Epoch 3/5
#  - 1104s - loss: 0.0664 - mean_absolute_error: 0.1827 - val_loss: 0.0672 - val_mean_absolute_error: 0.1778
#
# Epoch 4/5
#  - 1134s - loss: 0.0657 - mean_absolute_error: 0.1813 - val_loss: 0.0658 - val_mean_absolute_error: 0.1863
#
# Epoch 5/5
#  - 1108s - loss: 0.0653 - mean_absolute_error: 0.1805 - val_loss: 0.0642 - val_mean_absolute_error: 0.1730
#
# Best loss of epoch:
# 0.06420885121435875
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 584s - loss: 0.0791 - mean_absolute_error: 0.2057 - val_loss: 0.0699 - val_mean_absolute_error: 0.1797
#
# Epoch 2/5
#  - 555s - loss: 0.0688 - mean_absolute_error: 0.1885 - val_loss: 0.0664 - val_mean_absolute_error: 0.1857
#
# Epoch 3/5
#  - 559s - loss: 0.0675 - mean_absolute_error: 0.1858 - val_loss: 0.0668 - val_mean_absolute_error: 0.1874
#
# Epoch 4/5
#  - 545s - loss: 0.0670 - mean_absolute_error: 0.1846 - val_loss: 0.0653 - val_mean_absolute_error: 0.1831
#
# Epoch 5/5
#  - 540s - loss: 0.0670 - mean_absolute_error: 0.1843 - val_loss: 0.0678 - val_mean_absolute_error: 0.1865
#
# Best loss of epoch:
# 0.06526019736938074
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 546s - loss: 0.0788 - mean_absolute_error: 0.2048 - val_loss: 0.0705 - val_mean_absolute_error: 0.1965
#
# Epoch 2/5
#  - 537s - loss: 0.0684 - mean_absolute_error: 0.1859 - val_loss: 0.0668 - val_mean_absolute_error: 0.1783
#
# Epoch 3/5
#  - 560s - loss: 0.0675 - mean_absolute_error: 0.1844 - val_loss: 0.0665 - val_mean_absolute_error: 0.1823
#
# Epoch 4/5
#  - 595s - loss: 0.0667 - mean_absolute_error: 0.1828 - val_loss: 0.0658 - val_mean_absolute_error: 0.1777
#
# Epoch 5/5
#  - 608s - loss: 0.0666 - mean_absolute_error: 0.1823 - val_loss: 0.0657 - val_mean_absolute_error: 0.1787
#
# Best loss of epoch:
# 0.06572520371457682
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 540s - loss: 0.0789 - mean_absolute_error: 0.2060 - val_loss: 0.0715 - val_mean_absolute_error: 0.1940
#
# Epoch 2/5
#  - 515s - loss: 0.0675 - mean_absolute_error: 0.1873 - val_loss: 0.0665 - val_mean_absolute_error: 0.1876
#
# Epoch 3/5
#  - 525s - loss: 0.0662 - mean_absolute_error: 0.1845 - val_loss: 0.0652 - val_mean_absolute_error: 0.1802
#
# Epoch 4/5
#  - 542s - loss: 0.0656 - mean_absolute_error: 0.1833 - val_loss: 0.0652 - val_mean_absolute_error: 0.1776
#
# Epoch 5/5
#  - 527s - loss: 0.0652 - mean_absolute_error: 0.1826 - val_loss: 0.0676 - val_mean_absolute_error: 0.1833
#
# Best loss of epoch:
# 0.06522543652089195
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 721s - loss: 0.0785 - mean_absolute_error: 0.2048 - val_loss: 0.0686 - val_mean_absolute_error: 0.1920
#
# Epoch 2/5
#  - 760s - loss: 0.0684 - mean_absolute_error: 0.1875 - val_loss: 0.0668 - val_mean_absolute_error: 0.1851
#
# Epoch 3/5
#  - 726s - loss: 0.0668 - mean_absolute_error: 0.1845 - val_loss: 0.0652 - val_mean_absolute_error: 0.1753
#
# Epoch 4/5
#  - 697s - loss: 0.0661 - mean_absolute_error: 0.1831 - val_loss: 0.0644 - val_mean_absolute_error: 0.1771
#
# Epoch 5/5
#  - 710s - loss: 0.0659 - mean_absolute_error: 0.1825 - val_loss: 0.0645 - val_mean_absolute_error: 0.1799
#
# Best loss of epoch:
# 0.06435382254258552
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 522s - loss: 0.0807 - mean_absolute_error: 0.2087 - val_loss: 0.0701 - val_mean_absolute_error: 0.1885
#
# Epoch 2/5
#  - 531s - loss: 0.0683 - mean_absolute_error: 0.1883 - val_loss: 0.0661 - val_mean_absolute_error: 0.1867
#
# Epoch 3/5
#  - 538s - loss: 0.0668 - mean_absolute_error: 0.1850 - val_loss: 0.0650 - val_mean_absolute_error: 0.1811
#
# Epoch 4/5
#  - 532s - loss: 0.0661 - mean_absolute_error: 0.1835 - val_loss: 0.0654 - val_mean_absolute_error: 0.1818
#
# Epoch 5/5
#  - 560s - loss: 0.0658 - mean_absolute_error: 0.1831 - val_loss: 0.0648 - val_mean_absolute_error: 0.1815
#
# Best loss of epoch:
# 0.06480389882391795
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 753s - loss: 0.0791 - mean_absolute_error: 0.2059 - val_loss: 0.0680 - val_mean_absolute_error: 0.1828
#
# Epoch 2/5
#  - 763s - loss: 0.0683 - mean_absolute_error: 0.1879 - val_loss: 0.0666 - val_mean_absolute_error: 0.1850
#
# Epoch 3/5
#  - 801s - loss: 0.0671 - mean_absolute_error: 0.1854 - val_loss: 0.0652 - val_mean_absolute_error: 0.1843
#
# Epoch 4/5
#  - 787s - loss: 0.0663 - mean_absolute_error: 0.1838 - val_loss: 0.0674 - val_mean_absolute_error: 0.1906
#
# Epoch 5/5
#  - 748s - loss: 0.0657 - mean_absolute_error: 0.1824 - val_loss: 0.0654 - val_mean_absolute_error: 0.1788
#
# Best loss of epoch:
# 0.06519583988807133
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 749s - loss: 0.0767 - mean_absolute_error: 0.2012 - val_loss: 0.0669 - val_mean_absolute_error: 0.1892
#
# Epoch 2/5
#  - 939s - loss: 0.0677 - mean_absolute_error: 0.1860 - val_loss: 0.0671 - val_mean_absolute_error: 0.1814
#
# Epoch 3/5
#  - 1175s - loss: 0.0664 - mean_absolute_error: 0.1835 - val_loss: 0.0650 - val_mean_absolute_error: 0.1750
#
# Epoch 4/5
#  - 1002s - loss: 0.0659 - mean_absolute_error: 0.1824 - val_loss: 0.0654 - val_mean_absolute_error: 0.1850
#
# Epoch 5/5
#  - 1060s - loss: 0.0656 - mean_absolute_error: 0.1818 - val_loss: 0.0651 - val_mean_absolute_error: 0.1750
#
# Best loss of epoch:
# 0.06495177080754577
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 561s - loss: 0.0780 - mean_absolute_error: 0.2045 - val_loss: 0.0676 - val_mean_absolute_error: 0.1866
#
# Epoch 2/5
#  - 536s - loss: 0.0669 - mean_absolute_error: 0.1836 - val_loss: 0.0658 - val_mean_absolute_error: 0.1832
#
# Epoch 3/5
#  - 528s - loss: 0.0658 - mean_absolute_error: 0.1807 - val_loss: 0.0645 - val_mean_absolute_error: 0.1769
#
# Epoch 4/5
#  - 529s - loss: 0.0653 - mean_absolute_error: 0.1795 - val_loss: 0.0655 - val_mean_absolute_error: 0.1879
#
# Epoch 5/5
#  - 528s - loss: 0.0652 - mean_absolute_error: 0.1791 - val_loss: 0.0659 - val_mean_absolute_error: 0.1856
#
# Best loss of epoch:
# 0.0645065135139232
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 536s - loss: 0.0780 - mean_absolute_error: 0.2042 - val_loss: 0.0699 - val_mean_absolute_error: 0.1888
#
# Epoch 2/5
#  - 535s - loss: 0.0674 - mean_absolute_error: 0.1861 - val_loss: 0.0663 - val_mean_absolute_error: 0.1781
#
# Epoch 3/5
#  - 541s - loss: 0.0664 - mean_absolute_error: 0.1838 - val_loss: 0.0664 - val_mean_absolute_error: 0.1788
#
# Epoch 4/5
#  - 664s - loss: 0.0658 - mean_absolute_error: 0.1822 - val_loss: 0.0657 - val_mean_absolute_error: 0.1784
#
# Epoch 5/5
#  - 775s - loss: 0.0655 - mean_absolute_error: 0.1813 - val_loss: 0.0645 - val_mean_absolute_error: 0.1828
#
# Best loss of epoch:
# 0.06453440106096678
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 857s - loss: 0.0781 - mean_absolute_error: 0.2042 - val_loss: 0.0664 - val_mean_absolute_error: 0.1809
#
# Epoch 2/5
#  - 922s - loss: 0.0675 - mean_absolute_error: 0.1845 - val_loss: 0.0650 - val_mean_absolute_error: 0.1768
#
# Epoch 3/5
#  - 856s - loss: 0.0665 - mean_absolute_error: 0.1822 - val_loss: 0.0648 - val_mean_absolute_error: 0.1784
#
# Epoch 4/5
#  - 857s - loss: 0.0658 - mean_absolute_error: 0.1803 - val_loss: 0.0660 - val_mean_absolute_error: 0.1747
#
# Epoch 5/5
#  - 981s - loss: 0.0654 - mean_absolute_error: 0.1795 - val_loss: 0.0643 - val_mean_absolute_error: 0.1775
#
# Best loss of epoch:
# 0.06434502698641541
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 900s - loss: 0.0783 - mean_absolute_error: 0.2045 - val_loss: 0.0700 - val_mean_absolute_error: 0.1918
#
# Epoch 2/5
#  - 916s - loss: 0.0680 - mean_absolute_error: 0.1872 - val_loss: 0.0652 - val_mean_absolute_error: 0.1808
#
# Epoch 3/5
#  - 939s - loss: 0.0672 - mean_absolute_error: 0.1853 - val_loss: 0.0668 - val_mean_absolute_error: 0.1861
#
# Epoch 4/5
#  - 958s - loss: 0.0669 - mean_absolute_error: 0.1846 - val_loss: 0.0681 - val_mean_absolute_error: 0.1962
#
# Epoch 5/5
#  - 908s - loss: 0.0668 - mean_absolute_error: 0.1845 - val_loss: 0.0673 - val_mean_absolute_error: 0.1801
#
# Best loss of epoch:
# 0.06524054390395385
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1282s - loss: 0.0785 - mean_absolute_error: 0.2041 - val_loss: 0.0695 - val_mean_absolute_error: 0.1912
#
# Epoch 2/5
#  - 1207s - loss: 0.0680 - mean_absolute_error: 0.1861 - val_loss: 0.0665 - val_mean_absolute_error: 0.1851
#
# Epoch 3/5
#  - 719s - loss: 0.0664 - mean_absolute_error: 0.1829 - val_loss: 0.0666 - val_mean_absolute_error: 0.1850
#
# Epoch 4/5
#  - 702s - loss: 0.0658 - mean_absolute_error: 0.1816 - val_loss: 0.0649 - val_mean_absolute_error: 0.1755
#
# Epoch 5/5
#  - 677s - loss: 0.0654 - mean_absolute_error: 0.1808 - val_loss: 0.0641 - val_mean_absolute_error: 0.1730
#
# Best loss of epoch:
# 0.06408747224869683
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 573s - loss: 0.0768 - mean_absolute_error: 0.2021 - val_loss: 0.0692 - val_mean_absolute_error: 0.1894
#
# Epoch 2/5
#  - 566s - loss: 0.0681 - mean_absolute_error: 0.1868 - val_loss: 0.0674 - val_mean_absolute_error: 0.1824
#
# Epoch 3/5
#  - 566s - loss: 0.0669 - mean_absolute_error: 0.1841 - val_loss: 0.0673 - val_mean_absolute_error: 0.1798
#
# Epoch 4/5
#  - 571s - loss: 0.0661 - mean_absolute_error: 0.1825 - val_loss: 0.0657 - val_mean_absolute_error: 0.1812
#
# Epoch 5/5
#  - 566s - loss: 0.0660 - mean_absolute_error: 0.1822 - val_loss: 0.0699 - val_mean_absolute_error: 0.1913
#
# Best loss of epoch:
# 0.06573095207408033
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 513s - loss: 0.0810 - mean_absolute_error: 0.2092 - val_loss: 0.0769 - val_mean_absolute_error: 0.1981
#
# Epoch 2/5
#  - 513s - loss: 0.0680 - mean_absolute_error: 0.1870 - val_loss: 0.0656 - val_mean_absolute_error: 0.1802
#
# Epoch 3/5
#  - 512s - loss: 0.0670 - mean_absolute_error: 0.1848 - val_loss: 0.0702 - val_mean_absolute_error: 0.1891
#
# Epoch 4/5
#  - 516s - loss: 0.0663 - mean_absolute_error: 0.1839 - val_loss: 0.0651 - val_mean_absolute_error: 0.1801
#
# Epoch 5/5
#  - 515s - loss: 0.0658 - mean_absolute_error: 0.1830 - val_loss: 0.0651 - val_mean_absolute_error: 0.1782
#
# Best loss of epoch:
# 0.06507134644507823
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 518s - loss: 0.0795 - mean_absolute_error: 0.2075 - val_loss: 0.0692 - val_mean_absolute_error: 0.1948
#
# Epoch 2/5
#  - 515s - loss: 0.0680 - mean_absolute_error: 0.1873 - val_loss: 0.0680 - val_mean_absolute_error: 0.1948
#
# Epoch 3/5
#  - 521s - loss: 0.0665 - mean_absolute_error: 0.1839 - val_loss: 0.0644 - val_mean_absolute_error: 0.1777
#
# Epoch 4/5
#  - 518s - loss: 0.0659 - mean_absolute_error: 0.1824 - val_loss: 0.0653 - val_mean_absolute_error: 0.1860
#
# Epoch 5/5
#  - 514s - loss: 0.0655 - mean_absolute_error: 0.1814 - val_loss: 0.0642 - val_mean_absolute_error: 0.1823
#
# Best loss of epoch:
# 0.0641977105824574
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 588s - loss: 0.0790 - mean_absolute_error: 0.2068 - val_loss: 0.0687 - val_mean_absolute_error: 0.1920
#
# Epoch 2/5
#  - 589s - loss: 0.0688 - mean_absolute_error: 0.1888 - val_loss: 0.0668 - val_mean_absolute_error: 0.1849
#
# Epoch 3/5
#  - 591s - loss: 0.0679 - mean_absolute_error: 0.1867 - val_loss: 0.0678 - val_mean_absolute_error: 0.1886
#
# Epoch 4/5
#  - 587s - loss: 0.0672 - mean_absolute_error: 0.1852 - val_loss: 0.0665 - val_mean_absolute_error: 0.1800
#
# Epoch 5/5
#  - 588s - loss: 0.0671 - mean_absolute_error: 0.1851 - val_loss: 0.0673 - val_mean_absolute_error: 0.1794
#
# Best loss of epoch:
# 0.06650952703790795
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 830s - loss: 0.0770 - mean_absolute_error: 0.2008 - val_loss: 0.0682 - val_mean_absolute_error: 0.1814
#
# Epoch 2/5
#  - 839s - loss: 0.0680 - mean_absolute_error: 0.1853 - val_loss: 0.0651 - val_mean_absolute_error: 0.1781
#
# Epoch 3/5
#  - 847s - loss: 0.0666 - mean_absolute_error: 0.1825 - val_loss: 0.0650 - val_mean_absolute_error: 0.1826
#
# Epoch 4/5
#  - 855s - loss: 0.0663 - mean_absolute_error: 0.1826 - val_loss: 0.0647 - val_mean_absolute_error: 0.1755
#
# Epoch 5/5
#  - 852s - loss: 0.0657 - mean_absolute_error: 0.1812 - val_loss: 0.0697 - val_mean_absolute_error: 0.1797
#
# Best loss of epoch:
# 0.06469178860388496
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 610s - loss: 0.0782 - mean_absolute_error: 0.2039 - val_loss: 0.0665 - val_mean_absolute_error: 0.1843
#
# Epoch 2/5
#  - 609s - loss: 0.0681 - mean_absolute_error: 0.1871 - val_loss: 0.0662 - val_mean_absolute_error: 0.1876
#
# Epoch 3/5
#  - 608s - loss: 0.0675 - mean_absolute_error: 0.1852 - val_loss: 0.0664 - val_mean_absolute_error: 0.1793
#
# Epoch 4/5
#  - 608s - loss: 0.0667 - mean_absolute_error: 0.1833 - val_loss: 0.0661 - val_mean_absolute_error: 0.1880
#
# Epoch 5/5
#  - 613s - loss: 0.0663 - mean_absolute_error: 0.1823 - val_loss: 0.0651 - val_mean_absolute_error: 0.1744
#
# Best loss of epoch:
# 0.06509411731488712
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 732s - loss: 0.0787 - mean_absolute_error: 0.2046 - val_loss: 0.0682 - val_mean_absolute_error: 0.1897
#
# Epoch 2/5
#  - 738s - loss: 0.0682 - mean_absolute_error: 0.1866 - val_loss: 0.0659 - val_mean_absolute_error: 0.1855
#
# Epoch 3/5
#  - 745s - loss: 0.0670 - mean_absolute_error: 0.1842 - val_loss: 0.0666 - val_mean_absolute_error: 0.1862
#
# Epoch 4/5
#  - 745s - loss: 0.0666 - mean_absolute_error: 0.1832 - val_loss: 0.0675 - val_mean_absolute_error: 0.1924
#
# Epoch 5/5
#  - 743s - loss: 0.0662 - mean_absolute_error: 0.1825 - val_loss: 0.0663 - val_mean_absolute_error: 0.1813
#
# Best loss of epoch:
# 0.06589583539178147
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 750s - loss: 0.0790 - mean_absolute_error: 0.2061 - val_loss: 0.0692 - val_mean_absolute_error: 0.1930
#
# Epoch 2/5
#  - 750s - loss: 0.0683 - mean_absolute_error: 0.1880 - val_loss: 0.0673 - val_mean_absolute_error: 0.1864
# Epoch 3/5
#  - 749s - loss: 0.0669 - mean_absolute_error: 0.1851 - val_loss: 0.0658 - val_mean_absolute_error: 0.1758
#
# Epoch 4/5
#  - 749s - loss: 0.0664 - mean_absolute_error: 0.1840 - val_loss: 0.0671 - val_mean_absolute_error: 0.1800
#
# Epoch 5/5
#  - 757s - loss: 0.0659 - mean_absolute_error: 0.1828 - val_loss: 0.0647 - val_mean_absolute_error: 0.1787
#
# Best loss of epoch:
# 0.06467627899550073
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 766s - loss: 0.0786 - mean_absolute_error: 0.2052 - val_loss: 0.0688 - val_mean_absolute_error: 0.1905
#
# Epoch 2/5
#  - 765s - loss: 0.0689 - mean_absolute_error: 0.1893 - val_loss: 0.0691 - val_mean_absolute_error: 0.1849
#
# Epoch 3/5
#  - 765s - loss: 0.0674 - mean_absolute_error: 0.1866 - val_loss: 0.0654 - val_mean_absolute_error: 0.1826
#
# Epoch 4/5
#  - 763s - loss: 0.0666 - mean_absolute_error: 0.1850 - val_loss: 0.0658 - val_mean_absolute_error: 0.1862
#
# Epoch 5/5
#  - 763s - loss: 0.0666 - mean_absolute_error: 0.1849 - val_loss: 0.0654 - val_mean_absolute_error: 0.1841
#
# Best loss of epoch:
# 0.06539626717117382
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 813s - loss: 0.0778 - mean_absolute_error: 0.2042 - val_loss: 0.0676 - val_mean_absolute_error: 0.1850
#
# Epoch 2/5
#  - 915s - loss: 0.0683 - mean_absolute_error: 0.1874 - val_loss: 0.0675 - val_mean_absolute_error: 0.1784
#
# Epoch 3/5
#  - 832s - loss: 0.0669 - mean_absolute_error: 0.1843 - val_loss: 0.0697 - val_mean_absolute_error: 0.1803
#
# Epoch 4/5
#  - 829s - loss: 0.0662 - mean_absolute_error: 0.1828 - val_loss: 0.0642 - val_mean_absolute_error: 0.1811
#
# Epoch 5/5
#  - 828s - loss: 0.0656 - mean_absolute_error: 0.1818 - val_loss: 0.0648 - val_mean_absolute_error: 0.1841
#
# Best loss of epoch:
# 0.06424712293363553
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 833s - loss: 0.0793 - mean_absolute_error: 0.2061 - val_loss: 0.0681 - val_mean_absolute_error: 0.1881
#
# Epoch 2/5
#  - 831s - loss: 0.0684 - mean_absolute_error: 0.1875 - val_loss: 0.0669 - val_mean_absolute_error: 0.1772
#
# Epoch 3/5
#  - 827s - loss: 0.0670 - mean_absolute_error: 0.1847 - val_loss: 0.0659 - val_mean_absolute_error: 0.1888
#
# Epoch 4/5
#  - 831s - loss: 0.0664 - mean_absolute_error: 0.1831 - val_loss: 0.0644 - val_mean_absolute_error: 0.1811
#
# Epoch 5/5
#  - 848s - loss: 0.0660 - mean_absolute_error: 0.1822 - val_loss: 0.0645 - val_mean_absolute_error: 0.1831
#
# Best loss of epoch:
# 0.06437546785628946
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 899s - loss: 0.0790 - mean_absolute_error: 0.2053 - val_loss: 0.0684 - val_mean_absolute_error: 0.1907
#
# Epoch 2/5
#  - 858s - loss: 0.0679 - mean_absolute_error: 0.1858 - val_loss: 0.0672 - val_mean_absolute_error: 0.1867
#
# Epoch 3/5
#  - 882s - loss: 0.0666 - mean_absolute_error: 0.1833 - val_loss: 0.0645 - val_mean_absolute_error: 0.1786
#
# Epoch 4/5
#  - 870s - loss: 0.0659 - mean_absolute_error: 0.1819 - val_loss: 0.0643 - val_mean_absolute_error: 0.1776
#
# Epoch 5/5
#  - 871s - loss: 0.0654 - mean_absolute_error: 0.1808 - val_loss: 0.0658 - val_mean_absolute_error: 0.1729
#
# Best loss of epoch:
# 0.06425154280634923
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 599s - loss: 0.0798 - mean_absolute_error: 0.2075 - val_loss: 0.0687 - val_mean_absolute_error: 0.1935
#
# Epoch 2/5
#  - 604s - loss: 0.0680 - mean_absolute_error: 0.1872 - val_loss: 0.0661 - val_mean_absolute_error: 0.1850
#
# Epoch 3/5
#  - 606s - loss: 0.0666 - mean_absolute_error: 0.1839 - val_loss: 0.0652 - val_mean_absolute_error: 0.1793
#
# Epoch 4/5
#  - 605s - loss: 0.0659 - mean_absolute_error: 0.1823 - val_loss: 0.0663 - val_mean_absolute_error: 0.1881
#
# Epoch 5/5
#  - 604s - loss: 0.0655 - mean_absolute_error: 0.1814 - val_loss: 0.0654 - val_mean_absolute_error: 0.1789
#
# Best loss of epoch:
# 0.06521957412294196
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 824s - loss: 0.0789 - mean_absolute_error: 0.2056 - val_loss: 0.0711 - val_mean_absolute_error: 0.1925
#
# Epoch 2/5
#  - 821s - loss: 0.0685 - mean_absolute_error: 0.1879 - val_loss: 0.0670 - val_mean_absolute_error: 0.1831
#
# Epoch 3/5
#  - 821s - loss: 0.0668 - mean_absolute_error: 0.1844 - val_loss: 0.0656 - val_mean_absolute_error: 0.1844
#
# Epoch 4/5
#  - 819s - loss: 0.0664 - mean_absolute_error: 0.1837 - val_loss: 0.0658 - val_mean_absolute_error: 0.1867
#
# Epoch 5/5
#  - 818s - loss: 0.0660 - mean_absolute_error: 0.1825 - val_loss: 0.0646 - val_mean_absolute_error: 0.1785
#
# Best loss of epoch:
# 0.06456548255417068
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 837s - loss: 0.0784 - mean_absolute_error: 0.2049 - val_loss: 0.0680 - val_mean_absolute_error: 0.1927
#
# Epoch 2/5
#  - 839s - loss: 0.0680 - mean_absolute_error: 0.1870 - val_loss: 0.0673 - val_mean_absolute_error: 0.1927
#
# Epoch 3/5
#  - 838s - loss: 0.0671 - mean_absolute_error: 0.1851 - val_loss: 0.0667 - val_mean_absolute_error: 0.1845
#
# Epoch 4/5
#  - 840s - loss: 0.0666 - mean_absolute_error: 0.1842 - val_loss: 0.0664 - val_mean_absolute_error: 0.1811
#
# Epoch 5/5
#  - 839s - loss: 0.0664 - mean_absolute_error: 0.1839 - val_loss: 0.0659 - val_mean_absolute_error: 0.1892
#
# Best loss of epoch:
# 0.06590028057709739
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 629s - loss: 0.0808 - mean_absolute_error: 0.2091 - val_loss: 0.0683 - val_mean_absolute_error: 0.1882
#
# Epoch 2/5
#  - 628s - loss: 0.0683 - mean_absolute_error: 0.1880 - val_loss: 0.0721 - val_mean_absolute_error: 0.1987
#
# Epoch 3/5
#  - 625s - loss: 0.0671 - mean_absolute_error: 0.1853 - val_loss: 0.0657 - val_mean_absolute_error: 0.1773
#
# Epoch 4/5
#  - 626s - loss: 0.0664 - mean_absolute_error: 0.1837 - val_loss: 0.0683 - val_mean_absolute_error: 0.1761
#
# Epoch 5/5
#  - 650s - loss: 0.0659 - mean_absolute_error: 0.1826 - val_loss: 0.0659 - val_mean_absolute_error: 0.1805
#
# Best loss of epoch:
# 0.06574800046697728
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 922s - loss: 0.0781 - mean_absolute_error: 0.2047 - val_loss: 0.0671 - val_mean_absolute_error: 0.1881
#
# Epoch 2/5
#  - 1713s - loss: 0.0683 - mean_absolute_error: 0.1882 - val_loss: 0.0660 - val_mean_absolute_error: 0.1853
#
# Epoch 3/5
#  - 1584s - loss: 0.0671 - mean_absolute_error: 0.1855 - val_loss: 0.0661 - val_mean_absolute_error: 0.1790
#
# Epoch 4/5
#  - 1882s - loss: 0.0664 - mean_absolute_error: 0.1841 - val_loss: 0.0649 - val_mean_absolute_error: 0.1810
#
# Epoch 5/5
#  - 1635s - loss: 0.0659 - mean_absolute_error: 0.1831 - val_loss: 0.0648 - val_mean_absolute_error: 0.1763
#
# Best loss of epoch:
# 0.06482605503392429
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 2103s - loss: 0.0785 - mean_absolute_error: 0.2052 - val_loss: 0.0683 - val_mean_absolute_error: 0.1914
#
# Epoch 2/5
#  - 1960s - loss: 0.0681 - mean_absolute_error: 0.1873 - val_loss: 0.0698 - val_mean_absolute_error: 0.1904
#
# Epoch 3/5
#  - 2069s - loss: 0.0669 - mean_absolute_error: 0.1840 - val_loss: 0.0649 - val_mean_absolute_error: 0.1813
#
# Epoch 4/5
#  - 1643s - loss: 0.0663 - mean_absolute_error: 0.1827 - val_loss: 0.0663 - val_mean_absolute_error: 0.1900
#
# Epoch 5/5
#  - 1870s - loss: 0.0659 - mean_absolute_error: 0.1821 - val_loss: 0.0673 - val_mean_absolute_error: 0.1744
#
# Best loss of epoch:
# 0.0649042459399681
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1340s - loss: 0.0794 - mean_absolute_error: 0.2072 - val_loss: 0.0684 - val_mean_absolute_error: 0.1889
#
# Epoch 2/5
#  - 703s - loss: 0.0683 - mean_absolute_error: 0.1886 - val_loss: 0.0675 - val_mean_absolute_error: 0.1877
#
# Epoch 3/5
#  - 649s - loss: 0.0672 - mean_absolute_error: 0.1859 - val_loss: 0.0672 - val_mean_absolute_error: 0.1917
#
# Epoch 4/5
#  - 649s - loss: 0.0664 - mean_absolute_error: 0.1841 - val_loss: 0.0669 - val_mean_absolute_error: 0.1859
#
# Epoch 5/5
#  - 646s - loss: 0.0660 - mean_absolute_error: 0.1833 - val_loss: 0.0650 - val_mean_absolute_error: 0.1817
#
# Best loss of epoch:
# 0.06500485334154121
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 659s - loss: 0.0789 - mean_absolute_error: 0.2066 - val_loss: 0.0680 - val_mean_absolute_error: 0.1871
#
# Epoch 2/5
#  - 660s - loss: 0.0675 - mean_absolute_error: 0.1868 - val_loss: 0.0656 - val_mean_absolute_error: 0.1840
#
# Epoch 3/5
#  - 660s - loss: 0.0663 - mean_absolute_error: 0.1841 - val_loss: 0.0657 - val_mean_absolute_error: 0.1814
#
# Epoch 4/5
# ...
#
# Epoch 4/5
#  - 1617s - loss: 0.0658 - mean_absolute_error: 0.1819 - val_loss: 0.0651 - val_mean_absolute_error: 0.1836
#
# Epoch 5/5
#  - 1615s - loss: 0.0653 - mean_absolute_error: 0.1809 - val_loss: 0.0648 - val_mean_absolute_error: 0.1800
#
# Best loss of epoch:
# 0.06479438976546151
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1152s - loss: 0.0798 - mean_absolute_error: 0.2071 - val_loss: 0.0681 - val_mean_absolute_error: 0.1911
#
# Epoch 2/5
#  - 1142s - loss: 0.0676 - mean_absolute_error: 0.1858 - val_loss: 0.0657 - val_mean_absolute_error: 0.1768
#
# Epoch 3/5
#  - 1150s - loss: 0.0662 - mean_absolute_error: 0.1827 - val_loss: 0.0654 - val_mean_absolute_error: 0.1787
#
# Epoch 4/5
#  - 1146s - loss: 0.0658 - mean_absolute_error: 0.1816 - val_loss: 0.0673 - val_mean_absolute_error: 0.1752
#
# Epoch 5/5
#  - 1154s - loss: 0.0655 - mean_absolute_error: 0.1806 - val_loss: 0.0649 - val_mean_absolute_error: 0.1840
#
# Best loss of epoch:
# 0.06489729873579352
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1154s - loss: 0.0775 - mean_absolute_error: 0.2034 - val_loss: 0.0691 - val_mean_absolute_error: 0.1910
#
# Epoch 2/5
#  - 1162s - loss: 0.0679 - mean_absolute_error: 0.1868 - val_loss: 0.0681 - val_mean_absolute_error: 0.1916
#
# Epoch 3/5
#  - 1152s - loss: 0.0667 - mean_absolute_error: 0.1843 - val_loss: 0.0670 - val_mean_absolute_error: 0.1839
#
# Epoch 4/5
#  - 1149s - loss: 0.0660 - mean_absolute_error: 0.1825 - val_loss: 0.0659 - val_mean_absolute_error: 0.1831
#
# Epoch 5/5
#  - 1149s - loss: 0.0657 - mean_absolute_error: 0.1817 - val_loss: 0.0651 - val_mean_absolute_error: 0.1814
#
# Best loss of epoch:
# 0.0651425067809691
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1184s - loss: 0.0800 - mean_absolute_error: 0.2075 - val_loss: 0.0705 - val_mean_absolute_error: 0.1886
#
# Epoch 2/5
#  - 1174s - loss: 0.0683 - mean_absolute_error: 0.1877 - val_loss: 0.0674 - val_mean_absolute_error: 0.1874
#
# Epoch 3/5
#  - 1173s - loss: 0.0668 - mean_absolute_error: 0.1843 - val_loss: 0.0662 - val_mean_absolute_error: 0.1818
#
# Epoch 4/5
#  - 1172s - loss: 0.0659 - mean_absolute_error: 0.1821 - val_loss: 0.0700 - val_mean_absolute_error: 0.1917
#
# Epoch 5/5
#  - 1174s - loss: 0.0653 - mean_absolute_error: 0.1810 - val_loss: 0.0637 - val_mean_absolute_error: 0.1781
#
# Best loss of epoch:
# 0.06374907422140458
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1721s - loss: 0.0779 - mean_absolute_error: 0.2038 - val_loss: 0.0680 - val_mean_absolute_error: 0.1832
#
# Epoch 2/5
#  - 1860s - loss: 0.0682 - mean_absolute_error: 0.1863 - val_loss: 0.0662 - val_mean_absolute_error: 0.1822
#
# Epoch 3/5
#  - 1665s - loss: 0.0665 - mean_absolute_error: 0.1831 - val_loss: 0.0675 - val_mean_absolute_error: 0.1777
#
# Epoch 4/5
#  - 1606s - loss: 0.0659 - mean_absolute_error: 0.1819 - val_loss: 0.0655 - val_mean_absolute_error: 0.1781
#
# Epoch 5/5
#  - 1606s - loss: 0.0657 - mean_absolute_error: 0.1813 - val_loss: 0.0660 - val_mean_absolute_error: 0.1782
#
# Best loss of epoch:
# 0.0654893100744162
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1259s - loss: 0.0774 - mean_absolute_error: 0.2033 - val_loss: 0.0669 - val_mean_absolute_error: 0.1825
#
# Epoch 2/5
#  - 1243s - loss: 0.0673 - mean_absolute_error: 0.1860 - val_loss: 0.0654 - val_mean_absolute_error: 0.1814
#
# Epoch 3/5
#  - 1243s - loss: 0.0661 - mean_absolute_error: 0.1834 - val_loss: 0.0642 - val_mean_absolute_error: 0.1790
#
# Epoch 4/5
#  - 1250s - loss: 0.0657 - mean_absolute_error: 0.1825 - val_loss: 0.0641 - val_mean_absolute_error: 0.1716
#
# Epoch 5/5
#  - 1252s - loss: 0.0654 - mean_absolute_error: 0.1816 - val_loss: 0.0639 - val_mean_absolute_error: 0.1786
#
# Best loss of epoch:
# 0.06391815718991888
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1310s - loss: 0.0783 - mean_absolute_error: 0.2048 - val_loss: 0.0768 - val_mean_absolute_error: 0.2021
#
# Epoch 2/5
#  - 1302s - loss: 0.0685 - mean_absolute_error: 0.1885 - val_loss: 0.0670 - val_mean_absolute_error: 0.1882
#
# Epoch 3/5
#  - 1303s - loss: 0.0673 - mean_absolute_error: 0.1860 - val_loss: 0.0666 - val_mean_absolute_error: 0.1870
#
# Epoch 4/5
#  - 1307s - loss: 0.0670 - mean_absolute_error: 0.1851 - val_loss: 0.0671 - val_mean_absolute_error: 0.1919
#
# Epoch 5/5
#  - 1308s - loss: 0.0671 - mean_absolute_error: 0.1853 - val_loss: 0.0661 - val_mean_absolute_error: 0.1858
#
# Best loss of epoch:
# 0.06608471020340662
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1286s - loss: 0.0785 - mean_absolute_error: 0.2054 - val_loss: 0.0679 - val_mean_absolute_error: 0.1870
#
# Epoch 2/5
#  - 1273s - loss: 0.0683 - mean_absolute_error: 0.1882 - val_loss: 0.0665 - val_mean_absolute_error: 0.1884
#
# Epoch 3/5
#  - 1274s - loss: 0.0673 - mean_absolute_error: 0.1858 - val_loss: 0.0690 - val_mean_absolute_error: 0.1891
#
# Epoch 4/5
#  - 1272s - loss: 0.0664 - mean_absolute_error: 0.1839 - val_loss: 0.0666 - val_mean_absolute_error: 0.1812
#
# Epoch 5/5
#  - 1273s - loss: 0.0661 - mean_absolute_error: 0.1831 - val_loss: 0.0658 - val_mean_absolute_error: 0.1867
#
# Best loss of epoch:
# 0.06575040286486766
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1293s - loss: 0.0778 - mean_absolute_error: 0.2045 - val_loss: 0.0675 - val_mean_absolute_error: 0.1863
#
# Epoch 2/5
#  - 1281s - loss: 0.0675 - mean_absolute_error: 0.1864 - val_loss: 0.0658 - val_mean_absolute_error: 0.1845
#
# Epoch 3/5
#  - 1280s - loss: 0.0664 - mean_absolute_error: 0.1843 - val_loss: 0.0654 - val_mean_absolute_error: 0.1806
#
# Epoch 4/5
#  - 1282s - loss: 0.0662 - mean_absolute_error: 0.1834 - val_loss: 0.0659 - val_mean_absolute_error: 0.1801
#
# Epoch 5/5
#  - 1281s - loss: 0.0656 - mean_absolute_error: 0.1821 - val_loss: 0.0664 - val_mean_absolute_error: 0.1873
#
# Best loss of epoch:
# 0.06535149268465247
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1801s - loss: 0.0779 - mean_absolute_error: 0.2025 - val_loss: 0.0658 - val_mean_absolute_error: 0.1833
#
# Epoch 2/5
#  - 1779s - loss: 0.0673 - mean_absolute_error: 0.1840 - val_loss: 0.0657 - val_mean_absolute_error: 0.1843
#
# Epoch 3/5
#  - 1781s - loss: 0.0664 - mean_absolute_error: 0.1823 - val_loss: 0.0664 - val_mean_absolute_error: 0.1874
#
# Epoch 4/5
#  - 1782s - loss: 0.0658 - mean_absolute_error: 0.1813 - val_loss: 0.0648 - val_mean_absolute_error: 0.1811
#
# Epoch 5/5
#  - 1786s - loss: 0.0654 - mean_absolute_error: 0.1806 - val_loss: 0.0679 - val_mean_absolute_error: 0.1868
#
# Best loss of epoch:
# 0.06476598513552402
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1335s - loss: 0.0785 - mean_absolute_error: 0.2052 - val_loss: 0.0724 - val_mean_absolute_error: 0.1951
#
# Epoch 2/5
#  - 1321s - loss: 0.0675 - mean_absolute_error: 0.1862 - val_loss: 0.0667 - val_mean_absolute_error: 0.1859
#
# Epoch 3/5
#  - 1321s - loss: 0.0664 - mean_absolute_error: 0.1839 - val_loss: 0.0657 - val_mean_absolute_error: 0.1839
#
# Epoch 4/5
#  - 1323s - loss: 0.0662 - mean_absolute_error: 0.1835 - val_loss: 0.0662 - val_mean_absolute_error: 0.1883
#
# Epoch 5/5
#  - 1429s - loss: 0.0658 - mean_absolute_error: 0.1828 - val_loss: 0.0654 - val_mean_absolute_error: 0.1863
#
# Best loss of epoch:
# 0.06535769468491341
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1409s - loss: 0.0769 - mean_absolute_error: 0.2025 - val_loss: 0.0669 - val_mean_absolute_error: 0.1826
#
# Epoch 2/5
#  - 1434s - loss: 0.0683 - mean_absolute_error: 0.1877 - val_loss: 0.0666 - val_mean_absolute_error: 0.1814
#
# Epoch 3/5
#  - 1365s - loss: 0.0676 - mean_absolute_error: 0.1857 - val_loss: 0.0673 - val_mean_absolute_error: 0.1849
#
# Epoch 4/5
#  - 1371s - loss: 0.0675 - mean_absolute_error: 0.1849 - val_loss: 0.0659 - val_mean_absolute_error: 0.1849
#
# Epoch 5/5
#  - 1374s - loss: 0.0672 - mean_absolute_error: 0.1841 - val_loss: 0.0666 - val_mean_absolute_error: 0.1896
#
# Best loss of epoch:
# 0.06592055790720638
# Train on 4507301 samples, validate on 237227 samples
# Epoch 1/5
#  - 1350s - loss: 0.0780 - mean_absolute_error: 0.2046 - val_loss: 0.0705 - val_mean_absolute_error: 0.1966
#
# Epoch 2/5
#  - 1348s - loss: 0.0678 - mean_absolute_error: 0.1874 - val_loss: 0.0658 - val_mean_absolute_error: 0.1805
#
# Epoch 3/5
#  - 1355s - loss: 0.0667 - mean_absolute_error: 0.1845 - val_loss: 0.0658 - val_mean_absolute_error: 0.1854
#
# Epoch 4/5
#  - 1343s - loss: 0.0662 - mean_absolute_error: 0.1835 - val_loss: 0.0655 - val_mean_absolute_error: 0.1799
#
# Epoch 5/5
#  - 1342s - loss: 0.0656 - mean_absolute_error: 0.1823 - val_loss: 0.0644 - val_mean_absolute_error: 0.1771
#
# Best loss of epoch:
# 0.06441278543900208
# 100%|██████████| 100/100 [134:44:22<00:00, 4850.62s/trial, best loss: 0.06374907422140458]

# %%
print("Hyper-parameters of best model in order:")

print(best_run)
# Out:
# Hyper-parameters of best model in order:
# {'Dense': 22, 'Dense_1': 24, 'Dense_2': 20, 'Dense_3': 'fifth_layer', 'Dense_4': 18, 'Dense_5': 'sixth_layer', 'Dense_6': 16, 'Dense_7': 6, 'Dense_8': 8, 'activationChoice': 'PReLU'}
